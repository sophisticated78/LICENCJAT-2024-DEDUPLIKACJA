# %%
import pandas as pd

from scipy.sparse import lil_matrix
from collections import Counter
from voyager import Index, Space

import sklearn
import networkx as nx

from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
url_census = 'https://raw.githubusercontent.com/djvanderlaan/tutorial-reclin-uros2021/main/data/census.csv'
url_cis = 'https://raw.githubusercontent.com/djvanderlaan/tutorial-reclin-uros2021/main/data/cis.csv'

# %%
#wczytanie danych
census = pd.read_csv(url_census)
cis = pd.read_csv(url_cis)

# %%
census.head()
# Out:
#       person_id pername1 pername2 sex  dob_day  dob_mon  dob_year  \
# 0  DE03US001001    COUIE    PRICE   M      1.0        6    1960.0
# 1  DE03US001002    ABBIE    PVICE   F      9.0       11    1961.0
# 2  DE03US001003    LACEY    PRICE   F      7.0        2    1999.0
# 3  DE03US001004   SAMUEL    PRICE   M     13.0        4    1990.0
# 4  DE03US001005   JOSEPH    PRICE   M     20.0        4    1986.0
#
#           enumcap  enumpc
# 0  1 WINDSOR ROAD  DE03US
# 1  1 WINDSOR ROAD  DE03US
# 2  1 WINDSOR ROAD  DE03US
# 3  1 WINDSOR ROAD  DE03US
# 4  1 WINDSOR ROAD  DE03US

# %%
#Utworzenie pliku z parami za pomocą person_id
cis.reset_index(inplace=True)
census.reset_index(inplace=True)
merged_df = pd.merge(census, cis, on='person_id', suffixes=('_census', '_cis'))
tp = merged_df[['index_census', 'index_cis']]
print(tp)
# Out:
#      index_census  index_cis
# 0              19      21255
# 1              34       9523
# 2              43       6753
# 3              80      17311
# 4              97      12385
# ..            ...        ...
# 966         25277      16237
# 967         25283      10250
# 968         25308      15945
# 969         25318       6675
# 970         25322      14776
#
# [971 rows x 2 columns]

# %%
#definiujemy funcję do złączenia wartości ze wszystkich kolumn
def concatenate_columns(row, dataframe):
    concatenated_string = ""
    for i in range(1, len(dataframe.columns)):
        value = row[i]
        if isinstance(value, str):
            value = value.lower()
            value = value.replace(" ", "")
        elif pd.isnull(value) or value == "null" or value == "nan":
            continue
        concatenated_string += str(value)
    return concatenated_string

# %%
#tworzymy puste kolumny
census['allInfo'] = None
cis['allInfo'] = None

# %%
#wypełniamy kolumny danymi
for i in range (0, len(census)):
    census.at[i, 'allInfo'] = concatenate_columns(census.iloc[i], census)

# %%
for i in range (0, len(cis)):
    cis.at[i, 'allInfo'] = concatenate_columns(cis.iloc[i], cis)

# %%
#definiujemy funkcję do generowania shingli
def generate_shingles(text, length):
    shingles = set()
    for i in range(len(text) - length + 1):
        shingle = text[i:i+length]
        shingles.add(shingle)
    return shingles

# %%
#ilość wierszy w pliku
n = census.shape[0]
n
# Out:
# 25343

# %%
#generujemy shingle dla pliku census
all_shingles_census_set = set()
for i, row in census.iterrows():
    all_shingles_census_set |= generate_shingles(row['allInfo'], 2)

print(len(all_shingles_census_set))
# Out:
# 1161

# %%
#rzutujemy zbiór na listę
all_shingles_census = list(all_shingles_census_set)
all_shingles_census_len = len(all_shingles_census)
print(all_shingles_census_len)
# Out:
# 1161

# %%
all_shingles_census
# Out:
# ['5i',
#  'sx',
#  'om',
#  'ov',
#  '05',
#  'za',
#  'tn',
#  'hv',
#  'kt',
#  'lf',
#  '1d',
#  '3z',
#  '9d',
#  'w4',
#  '6p',
#  'hi',
#  '1h',
#  'ap',
#  'wn',
#  'b8',
#  'fm',
#  '2b',
#  '56',
#  '9a',
#  'jt',
#  '7z',
#  'ol',
#  'ox',
#  'eh',
#  'nh',
#  '9u',
#  'e-',
#  're',
#  'sp',
#  'ml',
#  'w7',
#  'xo',
#  'rx',
#  '1r',
#  '3s',
#  'bs',
#  'n1',
#  'mj',
#  'hl',
#  '4v',
#  'ju',
#  'sz',
#  '5s',
#  '94',
#  '1e',
#  't2',
#  'g9',
#  'm8',
#  '8r',
#  'ku',
#  'rm',
#  'y2',
#  'cc',
#  'bb',
#  'yq',
#  'rb',
#  '0m',
#  '6z',
#  '8t',
#  'fp',
#  'lv',
#  'rp',
#  '4m',
#  'x0',
#  'ez',
#  'wi',
#  '23',
#  'tj',
#  'l2',
#  'zb',
#  'ly',
#  'y0',
#  '01',
#  'x3',
#  'lk',
#  'mi',
#  'rl',
#  'ug',
#  'qq',
#  'ot',
#  'jx',
#  'ze',
#  'g2',
#  'iw',
#  'c1',
#  'n8',
#  'no',
#  'pq',
#  'mv',
#  '30',
#  '91',
#  '74',
#  '8n',
#  'dp',
#  'pe',
#  'mr',
#  '9y',
#  'jj',
#  '1b',
#  '17',
#  's0',
#  '9.',
#  'i-',
#  'ao',
#  'f7',
#  '3p',
#  'ig',
#  'fk',
#  'xq',
#  'xr',
#  'bn',
#  'cu',
#  '8f',
#  '2q',
#  '3q',
#  '8q',
#  '8g',
#  'w6',
#  'k2',
#  'k1',
#  'gm',
#  'us',
#  'fu',
#  'pl',
#  'ya',
#  'dr',
#  'xx',
#  '5o',
#  '8w',
#  'q0',
#  '87',
#  '1v',
#  '0l',
#  'ru',
#  'ei',
#  'm9',
#  '1c',
#  '3h',
#  'ie',
#  'gv',
#  's6',
#  'ga',
#  '58',
#  '6k',
#  '.j',
#  '7v',
#  '8o',
#  'ue',
#  'at',
#  'ar',
#  '39',
#  'tz',
#  '4u',
#  '9i',
#  't7',
#  'uy',
#  '7q',
#  'du',
#  'aj',
#  'x4',
#  'yb',
#  'fi',
#  '5v',
#  'k8',
#  'ks',
#  '99',
#  's3',
#  '5e',
#  'ea',
#  '5g',
#  'jr',
#  'ui',
#  'v7',
#  'xb',
#  'nc',
#  '5n',
#  'qe',
#  'em',
#  '0c',
#  'uz',
#  'rq',
#  'mt',
#  'qb',
#  '45',
#  'm3',
#  '53',
#  '8h',
#  '6f',
#  'ye',
#  '3n',
#  'ce',
#  'r0',
#  'zq',
#  'hy',
#  'es',
#  'fe',
#  '9r',
#  'zu',
#  'ch',
#  'm5',
#  '6n',
#  '7m',
#  'am',
#  'cg',
#  'qx',
#  '6g',
#  'hr',
#  'be',
#  '9s',
#  'dg',
#  '7j',
#  'sq',
#  '00',
#  'bc',
#  '4q',
#  '8d',
#  'xj',
#  'do',
#  '7a',
#  'g6',
#  'xs',
#  'tu',
#  '3i',
#  '1a',
#  'vh',
#  'aq',
#  'dm',
#  '9f',
#  '0y',
#  '2o',
#  'rf',
#  'av',
#  'ro',
#  'ak',
#  '41',
#  'fa',
#  'uu',
#  '63',
#  'aw',
#  'if',
#  'td',
#  'qf',
#  'lx',
#  '1z',
#  'bm',
#  'a0',
#  'ik',
#  'ra',
#  'zh',
#  '5h',
#  's2',
#  'ej',
#  '80',
#  'eu',
#  'zy',
#  'lq',
#  '5.',
#  'sy',
#  'tf',
#  'ec',
#  'bv',
#  '8c',
#  '8y',
#  'ko',
#  'jq',
#  'ky',
#  't4',
#  'pp',
#  '3c',
#  'dy',
#  'ih',
#  'od',
#  '8m',
#  'hh',
#  '0v',
#  'yw',
#  'bf',
#  'w5',
#  'el',
#  'hb',
#  '44',
#  'zr',
#  'sg',
#  'nt',
#  '9x',
#  '93',
#  '6d',
#  '3y',
#  '21',
#  'sb',
#  '2.',
#  '7s',
#  'va',
#  'ln',
#  'w8',
#  '5m',
#  'ib',
#  'r5',
#  's8',
#  'zw',
#  '6v',
#  'uo',
#  '9z',
#  '7r',
#  'u1',
#  'cp',
#  'xg',
#  'o4',
#  'ax',
#  'gs',
#  '6c',
#  'bd',
#  'r8',
#  '1p',
#  '2t',
#  'vj',
#  '0n',
#  'dn',
#  'wt',
#  'cw',
#  '5c',
#  '07',
#  'x5',
#  'gf',
#  '4y',
#  'ic',
#  'r6',
#  '0a',
#  '68',
#  'lt',
#  'ow',
#  'xc',
#  '4i',
#  'tb',
#  '6y',
#  'ti',
#  '2l',
#  'ai',
#  'lc',
#  'ub',
#  'gy',
#  'cv',
#  'yx',
#  '5t',
#  'ym',
#  '3v',
#  '73',
#  'mb',
#  'la',
#  '76',
#  '2c',
#  '7i',
#  '49',
#  'yj',
#  'af',
#  'ew',
#  's7',
#  'uf',
#  'id',
#  'bi',
#  'tl',
#  '0s',
#  '0g',
#  'ij',
#  'kl',
#  '20',
#  '4f',
#  'mw',
#  'oj',
#  'zg',
#  'xp',
#  '3j',
#  '2h',
#  'x9',
#  '84',
#  'r4',
#  'mg',
#  '9o',
#  'ey',
#  'js',
#  't.',
#  'gn',
#  'z0',
#  'io',
#  'g7',
#  '3b',
#  '67',
#  '5j',
#  'yv',
#  'ef',
#  'sj',
#  'yz',
#  'e2',
#  '4.',
#  'nr',
#  'sa',
#  'iz',
#  '4j',
#  'ev',
#  '7b',
#  'ac',
#  'go',
#  'qa',
#  'rv',
#  '04',
#  '5r',
#  'gi',
#  '98',
#  '5z',
#  'ct',
#  '3x',
#  '2v',
#  'zn',
#  'nv',
#  '1s',
#  '8i',
#  'vw',
#  'nu',
#  'xm',
#  'bt',
#  'qu',
#  'er',
#  'fv',
#  'bl',
#  'ny',
#  'j1',
#  'tk',
#  'eo',
#  'dh',
#  'pb',
#  '-m',
#  'yc',
#  '72',
#  'is',
#  'wk',
#  'yg',
#  'qr',
#  'e1',
#  'y1',
#  '6x',
#  'hm',
#  'pf',
#  'rh',
#  'au',
#  'ww',
#  'gr',
#  'yp',
#  'x1',
#  'm7',
#  'o3',
#  '5f',
#  'b0',
#  'wp',
#  'ki',
#  'g0',
#  'py',
#  'n6',
#  'e8',
#  'zi',
#  'dq',
#  'ta',
#  'jo',
#  'm6',
#  '.0',
#  'fc',
#  'n2',
#  'kh',
#  '28',
#  'zo',
#  'zd',
#  '1w',
#  'hj',
#  'xa',
#  '77',
#  'eb',
#  'r9',
#  '7g',
#  'gj',
#  'sw',
#  'yd',
#  'oy',
#  'oe',
#  'sm',
#  'gw',
#  '7d',
#  '2x',
#  '8j',
#  '8l',
#  '29',
#  'lz',
#  '6s',
#  'h1',
#  '3o',
#  'vp',
#  '8e',
#  'w2',
#  'vm',
#  '3u',
#  'fr',
#  'oo',
#  'ri',
#  'an',
#  'vc',
#  'rs',
#  '40',
#  'xv',
#  'rj',
#  '6w',
#  'l9',
#  'y-',
#  'g1',
#  'gk',
#  'gu',
#  'hk',
#  'cm',
#  'ty',
#  'we',
#  'mc',
#  'dt',
#  'vs',
#  '9e',
#  'dx',
#  'x7',
#  's9',
#  '0p',
#  '19',
#  'ke',
#  'hp',
#  '9w',
#  'zc',
#  '6r',
#  '70',
#  '51',
#  'ys',
#  '82',
#  'ns',
#  'wh',
#  '2j',
#  'ok',
#  'kr',
#  '54',
#  'dj',
#  '4n',
#  'ck',
#  'vr',
#  'd6',
#  '95',
#  '31',
#  'vd',
#  'bz',
#  'pz',
#  '2i',
#  'iu',
#  '24',
#  '9m',
#  'si',
#  'zz',
#  '08',
#  'l1',
#  'oi',
#  'n4',
#  'd1',
#  '6b',
#  '0t',
#  '1x',
#  'tt',
#  '4l',
#  'f6',
#  '89',
#  've',
#  'ua',
#  '0r',
#  'h0',
#  'hs',
#  'ma',
#  'on',
#  'po',
#  'qp',
#  '5b',
#  'w1',
#  '1g',
#  'qd',
#  'yk',
#  'hn',
#  '8p',
#  '8a',
#  'jz',
#  '0u',
#  '9v',
#  '9p',
#  '2z',
#  'ay',
#  '4r',
#  'sl',
#  '0x',
#  '5q',
#  '3d',
#  'ir',
#  'bh',
#  'vv',
#  '9b',
#  'xn',
#  'jl',
#  '5x',
#  '6j',
#  'ep',
#  'nk',
#  'j0',
#  '3r',
#  'rn',
#  'hf',
#  'xt',
#  'xw',
#  'uc',
#  'rw',
#  'o2',
#  'mf',
#  'cd',
#  'pr',
#  '4t',
#  'hd',
#  'mp',
#  '33',
#  'df',
#  'd4',
#  'sh',
#  '0e',
#  'uv',
#  'y4',
#  '4h',
#  'f1',
#  'ja',
#  '7k',
#  '10',
#  'kd',
#  'ux',
#  'ae',
#  'so',
#  'mk',
#  '8k',
#  '4e',
#  'pg',
#  'fd',
#  'hx',
#  '8.',
#  'qz',
#  'kv',
#  '03',
#  'hg',
#  'wd',
#  'mn',
#  'cs',
#  'dl',
#  'ee',
#  '4o',
#  'l5',
#  'l4',
#  'oc',
#  '9q',
#  'tg',
#  '61',
#  'bp',
#  'as',
#  'zm',
#  'wo',
#  'ph',
#  '42',
#  'ms',
#  'og',
#  '2d',
#  '7n',
#  'g8',
#  '75',
#  'e5',
#  'bx',
#  '2k',
#  'bw',
#  '4a',
#  'r1',
#  'wq',
#  'd7',
#  'zf',
#  'en',
#  'vi',
#  '97',
#  '6q',
#  '2f',
#  'xe',
#  'dc',
#  '8b',
#  'lm',
#  'sv',
#  'te',
#  'n9',
#  'hu',
#  '14',
#  '1j',
#  '7l',
#  'na',
#  'pm',
#  'px',
#  '16',
#  'yo',
#  'ff',
#  '2s',
#  'ft',
#  't1',
#  '7o',
#  '2u',
#  '-l',
#  'yt',
#  'fl',
#  'um',
#  'ab',
#  'f2',
#  'fb',
#  '6a',
#  'sd',
#  'kp',
#  'nz',
#  'yu',
#  'sf',
#  'bo',
#  'x2',
#  'f5',
#  'fh',
#  'wj',
#  'ds',
#  'ip',
#  'rk',
#  '96',
#  'km',
#  'vt',
#  'kk',
#  'o8',
#  'd9',
#  'vu',
#  'g4',
#  'vk',
#  '32',
#  '4z',
#  'b3',
#  'ed',
#  'nl',
#  'r7',
#  '0z',
#  'dk',
#  '6i',
#  'ci',
#  '34',
#  'kc',
#  '26',
#  'ii',
#  '6o',
#  'mz',
#  '3a',
#  'rt',
#  'f9',
#  'nx',
#  'dw',
#  't6',
#  'jg',
#  '1m',
#  'im',
#  'qg',
#  'f0',
#  'o9',
#  'in',
#  'rd',
#  'bu',
#  '2g',
#  'yy',
#  '8v',
#  'e3',
#  '7x',
#  'ps',
#  'e0',
#  'e7',
#  'v1',
#  'ws',
#  'nj',
#  'yr',
#  '9h',
#  'yl',
#  'np',
#  'o1',
#  'cr',
#  '0.',
#  '12',
#  '4d',
#  '35',
#  'ut',
#  's5',
#  'xu',
#  'pk',
#  '13',
#  'or',
#  '1o',
#  '47',
#  '6e',
#  'mu',
#  'lj',
#  'd8',
#  '18',
#  'of',
#  'cf',
#  'wu',
#  '1f',
#  '0j',
#  '88',
#  'o7',
#  'wl',
#  'r3',
#  '62',
#  '5w',
#  '36',
#  '46',
#  'gh',
#  '25',
#  'cj',
#  'uh',
#  '0h',
#  'iy',
#  'tq',
#  'ix',
#  'qs',
#  '3w',
#  'c2',
#  '6t',
#  'fq',
#  '0f',
#  'cn',
#  'l3',
#  'hc',
#  'n0',
#  'fj',
#  'jn',
#  'tm',
#  'xf',
#  '9j',
#  'lb',
#  'jh',
#  'uj',
#  'gp',
#  'ah',
#  '59',
#  '9c',
#  'eq',
#  'jf',
#  'lr',
#  'iq',
#  'bj',
#  '7.',
#  'bg',
#  '9k',
#  'kn',
#  'gz',
#  'me',
#  'th',
#  'kg',
#  '1n',
#  '50',
#  'le',
#  '4g',
#  '48',
#  'wa',
#  'je',
#  'cx',
#  '81',
#  'zp',
#  '5a',
#  's1',
#  'st',
#  '2w',
#  'lh',
#  '27',
#  'ji',
#  'vo',
#  '60',
#  'rc',
#  'xy',
#  '78',
#  'hz',
#  'gb',
#  '7u',
#  'h9',
#  'pd',
#  'mo',
#  'gg',
#  'yh',
#  'ou',
#  'wz',
#  'vf',
#  'nq',
#  'kb',
#  '64',
#  '5l',
#  'da',
#  't3',
#  '2p',
#  'ud',
#  'f3',
#  'md',
#  '3k',
#  'op',
#  'e4',
#  '06',
#  'ka',
#  'w3',
#  'kf',
#  '4w',
#  'ry',
#  'dv',
#  'lu',
#  '0b',
#  'lw',
#  'd3',
#  'yn',
#  'qw',
#  '71',
#  'kw',
#  'gl',
#  'xl',
#  '1k',
#  'gd',
#  'et',
#  '1.',
#  'fy',
#  '5d',
#  'b2',
#  '65',
#  '6h',
#  'zj',
#  'pu',
#  '38',
#  '4s',
#  'up',
#  'un',
#  'pv',
#  '3e',
#  'wg',
#  'se',
#  '5y',
#  '4c',
#  '8x',
#  '7e',
#  '57',
#  'w9',
#  'wb',
#  'x8',
#  'mm',
#  '1y',
#  '8s',
#  'nb',
#  'jp',
#  'oh',
#  '6m',
#  'ca',
#  'yf',
#  'zs',
#  '37',
#  'ek',
#  '22',
#  'db',
#  '5p',
#  '9t',
#  'nd',
#  'it',
#  'fo',
#  'dz',
#  'sr',
#  '4p',
#  'ld',
#  '7p',
#  '3.',
#  'ba',
#  'cy',
#  's4',
#  'ge',
#  'y8',
#  'kj',
#  'rg',
#  '7c',
#  '85',
#  'il',
#  '1q',
#  'fw',
#  'p0',
#  'ho',
#  'ng',
#  'bk',
#  'o5',
#  '2e',
#  'my',
#  'de',
#  ...]

# %%
#tworzymy rzadką macierz wystąpień dla filtered_census
occurrence_matrix_census = lil_matrix((n, all_shingles_census_len), dtype=int)


for i, row in census.iterrows():
    shingles_in_text = generate_shingles(row['allInfo'], 2)
    shingle_counts = Counter(shingles_in_text)
    for j, shingle in enumerate(all_shingles_census):
        if shingle in shingle_counts:
            occurrence_matrix_census[i, j] = shingle_counts[shingle]

sparse_matrix_census = occurrence_matrix_census.tocsr()

# %%
#tworzymy rzadką macierz wystąpień dla cis
occurrence_matrix_cis = lil_matrix((len(cis), all_shingles_census_len), dtype=int)
all_shingles_list = list(all_shingles_census)
for i, row in cis.iterrows():
    shingles_in_text = generate_shingles(row['allInfo'], 2)
    shingle_counts = Counter(shingles_in_text)
    for j, shingle in enumerate(all_shingles_census[:all_shingles_census_len]):
        if shingle in shingles_in_text:

            occurrence_count = shingle_counts.get(shingle, 0)

            occurrence_matrix_cis[i, j] = occurrence_count

sparse_matrix_cis = occurrence_matrix_cis.tocsr()

# %%
sparse_matrix_census.shape, sparse_matrix_cis.shape
# Out:
# ((25343, 1161), (24613, 1161))

# %%
#tworzymy index voyagera dla cis
index_cis = Index(Space.Cosine, num_dimensions=all_shingles_census_len)

for i in range(len(cis)):
    index_cis.add_item(sparse_matrix_cis[i].toarray().flatten())

# %%
#sprawdzenie czy działa
neighbors, distances = index_cis.query(sparse_matrix_census[1].toarray().flatten(), k=3)

print(neighbors)
print(distances)
# Out:
# [ 8583  8151 20589]
# [0.11501491 0.30677998 0.32324684]

# %%
print(cis.iloc[8583])
print(census.iloc[1])
# Out:
# index                                            8583
# person_id                                         NaN
# pername1                                        ABBIE
# pername2                                        PRICE
# sex                                                 F
# dob_day                                           9.0
# dob_mon                                            11
# dob_year                                       1961.0
# enumcap                                1 WINDSOR ROAD
# enumpc                                         DE03US
# allInfo      abbiepricef9.0111961.01windsorroadde03us
# Name: 8583, dtype: object
# index                                                        1
# person_id                                         DE03US001002
# pername1                                                 ABBIE
# pername2                                                 PVICE
# sex                                                          F
# dob_day                                                    9.0
# dob_mon                                                     11
# dob_year                                                1961.0
# enumcap                                         1 WINDSOR ROAD
# enumpc                                                  DE03US
# allInfo      de03us001002abbiepvicef9.0111961.01windsorroad...
# Name: 1, dtype: object

# %%
#tworzymy csv z parami rekord - najbliższy sąsiad
pairs = []

for i in range(sparse_matrix_census.shape[0]):
    query_vector_census = sparse_matrix_census[i].toarray().flatten()
    neighbor, distance = index_cis.query(query_vector_census, k=50)
    index_neighbor = neighbor[0]
    index = f'A{i}'
    nearest_neighbor = f'B{str(index_neighbor).replace("[", "").replace("]", "")}'
    distance = str(distance[0]).replace("[", "").replace("]", "")
    fdistance = float(distance)
    pairs.append((index, nearest_neighbor, fdistance))

# Konwertuj listę tupli na DataFrame
df = pd.DataFrame(pairs, columns=['index_census', 'index_cis', 'Distance'])
df.head()
# Out:
#   index_census index_cis  Distance
# 0           A0     B8151  0.075707
# 1           A1     B8583  0.115015
# 2           A2    B20589  0.065919
# 3           A3    B18455  0.110425
# 4           A4    B17256  0.095136

# %%
Gr = nx.Graph()

for i in range(len(census)):
    Gr.add_node(f'A{i}', record=census.iloc[[i]])

for j in range(len(cis)):
    Gr.add_node(f'B{j}', record=cis.iloc[[j]])


for _, row in df.iterrows():
    if row['Distance'] < 0.4:
        Gr.add_edges_from([(row["index_census"], row["index_cis"])])

# %%
found_pairs = [component for component in nx.connected_components(Gr) if len(component) > 1 ]
len(found_pairs)
# Out:
# 23789

# %%
found_pairs
# Out:
# [{'A0', 'B8151'},
#  {'A1', 'B8583'},
#  {'A2', 'B20589'},
#  {'A3', 'B18455'},
#  {'A4', 'B17256'},
#  {'A5', 'B19867'},
#  {'A6', 'B11182'},
#  {'A34', 'A7', 'B9523'},
#  {'A9', 'B9369'},
#  {'A10', 'B7246'},
#  {'A11', 'B10621'},
#  {'A12', 'B5851'},
#  {'A13', 'B3911'},
#  {'A14', 'B20886'},
#  {'A15', 'B6410'},
#  {'A16', 'B17805'},
#  {'A17', 'B13508'},
#  {'A18', 'A21', 'B13588'},
#  {'A19', 'B21255'},
#  {'A20', 'B20764'},
#  {'A22', 'B5848'},
#  {'A23', 'B6038'},
#  {'A24', 'B12662'},
#  {'A25', 'B23168'},
#  {'A26', 'B13402'},
#  {'A27', 'B8172'},
#  {'A28', 'B14057'},
#  {'A29', 'B11612'},
#  {'A30', 'B18890'},
#  {'A31', 'B6089'},
#  {'A32', 'B20850'},
#  {'A33', 'B9826'},
#  {'A35', 'B21665'},
#  {'A36', 'B16805'},
#  {'A37', 'B16537'},
#  {'A38', 'B24166'},
#  {'A39', 'B24085'},
#  {'A40', 'B1722'},
#  {'A41', 'B6607'},
#  {'A42', 'B833'},
#  {'A43', 'B6753'},
#  {'A44', 'B2955'},
#  {'A45', 'B2836'},
#  {'A46', 'B4242'},
#  {'A47', 'B9221'},
#  {'A48', 'B22329'},
#  {'A49', 'B5323'},
#  {'A50', 'B5128'},
#  {'A51', 'B12941'},
#  {'A53', 'A54', 'B2718'},
#  {'A55', 'B17584'},
#  {'A56', 'B5682'},
#  {'A57', 'B5791'},
#  {'A58', 'B10466'},
#  {'A59', 'B9886'},
#  {'A60', 'B23762'},
#  {'A61', 'B14792'},
#  {'A62', 'B2952'},
#  {'A63', 'B1604'},
#  {'A64', 'B2987'},
#  {'A65', 'B3528'},
#  {'A66', 'B3036'},
#  {'A67', 'B1582'},
#  {'A68', 'B6090'},
#  {'A69', 'B6568'},
#  {'A70', 'B13823'},
#  {'A71', 'B11275'},
#  {'A72', 'B9085'},
#  {'A73', 'B4878'},
#  {'A74', 'B3932'},
#  {'A75', 'B2346'},
#  {'A76', 'B1977'},
#  {'A77', 'B4586'},
#  {'A78', 'B14572'},
#  {'A79', 'B3122'},
#  {'A80', 'B17311'},
#  {'A81', 'B7248'},
#  {'A82', 'B19824'},
#  {'A83', 'B11012'},
#  {'A84', 'B9528'},
#  {'A85', 'B10875'},
#  {'A86', 'B15793'},
#  {'A87', 'B12172'},
#  {'A88', 'B11563'},
#  {'A89', 'B19039'},
#  {'A90', 'B20325'},
#  {'A91', 'B13327'},
#  {'A92', 'B3472'},
#  {'A93', 'B13747'},
#  {'A94', 'B13935'},
#  {'A95', 'B22107'},
#  {'A96', 'B4255'},
#  {'A97', 'B12385'},
#  {'A98', 'B16817'},
#  {'A99', 'B4953'},
#  {'A100', 'B10550'},
#  {'A101', 'B4066'},
#  {'A102', 'B21718'},
#  {'A103', 'B17780'},
#  {'A104', 'B13071'},
#  {'A105', 'B14502'},
#  {'A106', 'B23290'},
#  {'A107', 'B8424'},
#  {'A108', 'B4800'},
#  {'A109', 'B6277'},
#  {'A110', 'A111', 'A112', 'B3870'},
#  {'A113', 'B21779'},
#  {'A114', 'B13140'},
#  {'A115', 'B16632'},
#  {'A116', 'B17497'},
#  {'A117', 'B23948'},
#  {'A118', 'B6805'},
#  {'A119', 'B4802'},
#  {'A120', 'B3649'},
#  {'A121', 'B14748'},
#  {'A122', 'B16406'},
#  {'A123', 'B24437'},
#  {'A124', 'B2435'},
#  {'A125', 'B11308'},
#  {'A126', 'B11613'},
#  {'A127', 'B23146'},
#  {'A128', 'B417'},
#  {'A129', 'B4296'},
#  {'A130', 'B2371'},
#  {'A131', 'B18983'},
#  {'A132', 'B1295'},
#  {'A133', 'B8237'},
#  {'A134', 'B1285'},
#  {'A135', 'B98'},
#  {'A136', 'B3246'},
#  {'A137', 'B18679'},
#  {'A138', 'B9433'},
#  {'A139', 'B757'},
#  {'A140', 'B2402'},
#  {'A141', 'B11737'},
#  {'A142', 'B11592'},
#  {'A143', 'B13035'},
#  {'A144', 'B20199'},
#  {'A145', 'B21738'},
#  {'A146', 'B20733'},
#  {'A147', 'B23109'},
#  {'A148', 'A149', 'B20342'},
#  {'A150', 'B23846'},
#  {'A151', 'B14910'},
#  {'A152', 'B11250'},
#  {'A153', 'A154', 'B18815'},
#  {'A155', 'B14927'},
#  {'A156', 'B14214'},
#  {'A157', 'B21821'},
#  {'A158', 'B16295'},
#  {'A159', 'B3892'},
#  {'A160', 'B1038'},
#  {'A161', 'B498'},
#  {'A162', 'B6020'},
#  {'A163', 'B13453'},
#  {'A164', 'B12887'},
#  {'A165', 'B20298'},
#  {'A166', 'B21289'},
#  {'A167', 'B21334'},
#  {'A168', 'B14176'},
#  {'A169', 'B14193'},
#  {'A170', 'B22784'},
#  {'A171', 'B10970'},
#  {'A172', 'B2197'},
#  {'A173', 'B18014'},
#  {'A174', 'B14498'},
#  {'A175', 'B20266'},
#  {'A176', 'B11190'},
#  {'A177', 'B18323'},
#  {'A178', 'B23401'},
#  {'A179', 'B21818'},
#  {'A180', 'B11153'},
#  {'A181', 'B10717'},
#  {'A182', 'B12152'},
#  {'A183', 'B21408'},
#  {'A184', 'B1914'},
#  {'A185', 'B16414'},
#  {'A186', 'B16902'},
#  {'A187', 'B5162'},
#  {'A188', 'B2596'},
#  {'A189', 'B16223'},
#  {'A190', 'B15437'},
#  {'A191', 'B1702'},
#  {'A192', 'B17219'},
#  {'A193', 'B18187'},
#  {'A194', 'B3270'},
#  {'A195', 'B11844'},
#  {'A196', 'A199', 'B15066'},
#  {'A197', 'B20546'},
#  {'A198', 'B21580'},
#  {'A200', 'B7090'},
#  {'A201', 'B13743'},
#  {'A202', 'B21740'},
#  {'A203', 'B404'},
#  {'A204', 'B11385'},
#  {'A205', 'B13185'},
#  {'A206', 'B8804'},
#  {'A207', 'B1982'},
#  {'A208', 'B16133'},
#  {'A209', 'B1114'},
#  {'A210', 'B6727'},
#  {'A211', 'B3955'},
#  {'A212', 'B17250'},
#  {'A213', 'B7772'},
#  {'A214', 'A215', 'B18158'},
#  {'A216', 'B10902'},
#  {'A217', 'A219', 'B23728'},
#  {'A218', 'B23264'},
#  {'A220', 'B18660'},
#  {'A221', 'B19063'},
#  {'A224', 'B410'},
#  {'A225', 'B3924'},
#  {'A226', 'A230', 'B4072'},
#  {'A227', 'B5200'},
#  {'A228', 'B2956'},
#  {'A229', 'B3804'},
#  {'A231', 'B2453'},
#  {'A232', 'B14635'},
#  {'A233', 'B14405'},
#  {'A234', 'B15804'},
#  {'A235', 'B23392'},
#  {'A236', 'B22612'},
#  {'A237', 'B8908'},
#  {'A238', 'B10062'},
#  {'A239', 'B19685'},
#  {'A240', 'B20879'},
#  {'A241', 'B18960'},
#  {'A242', 'B19587'},
#  {'A243', 'B3071'},
#  {'A244', 'B14846'},
#  {'A245', 'B14919'},
#  {'A246', 'B21897'},
#  {'A247', 'B21372'},
#  {'A248', 'B24118'},
#  {'A249', 'B23037'},
#  {'A250', 'B5745'},
#  {'A251', 'B16397'},
#  {'A252', 'B7606'},
#  {'A253', 'B18183'},
#  {'A254', 'B17906'},
#  {'A255', 'B15869'},
#  {'A256', 'B16610'},
#  {'A257', 'A259', 'B15531'},
#  {'A258', 'B23101'},
#  {'A260', 'B7328'},
#  {'A261', 'B4287'},
#  {'A262', 'B9662'},
#  {'A263', 'B10740'},
#  {'A264', 'B18567'},
#  {'A265', 'B16259'},
#  {'A266', 'B16510'},
#  {'A267', 'B17199'},
#  {'A268', 'B23399'},
#  {'A269', 'B23125'},
#  {'A270', 'B22970'},
#  {'A271', 'B9465'},
#  {'A272', 'B8849'},
#  {'A273', 'A299', 'B21395'},
#  {'A274', 'B13219'},
#  {'A275', 'B3017'},
#  {'A276', 'B8917'},
#  {'A277', 'A278', 'B10162'},
#  {'A279', 'B18792'},
#  {'A280', 'B1709'},
#  {'A281', 'A289', 'B11063'},
#  {'A282', 'B15801'},
#  {'A283', 'B14815'},
#  {'A284', 'B3516'},
#  {'A285', 'A287', 'B20161'},
#  {'A286', 'A288', 'B19916'},
#  {'A290', 'B19189'},
#  {'A291', 'B3332'},
#  {'A292', 'A293', 'B3655'},
#  {'A294', 'B2433'},
#  {'A295', 'B2092'},
#  {'A296', 'A297', 'B13054'},
#  {'A298', 'B1006'},
#  {'A300', 'B4147'},
#  {'A301', 'B13485'},
#  {'A302', 'B14048'},
#  {'A303', 'B21545'},
#  {'A304', 'B21791'},
#  {'A305', 'B814'},
#  {'A306', 'B7545'},
#  {'A307', 'B12953'},
#  {'A308', 'B14396'},
#  {'A309', 'B20617'},
#  {'A310', 'B7938'},
#  {'A311', 'A314', 'A315', 'B21214'},
#  {'A312', 'A313', 'B22361'},
#  {'A316', 'B14415'},
#  {'A317', 'B16218'},
#  {'A318', 'B23202'},
#  {'A319', 'B16066'},
#  {'A320', 'B19132'},
#  {'A321', 'B856'},
#  {'A322', 'B10570'},
#  {'A323', 'B19906'},
#  {'A324', 'B15298'},
#  {'A325', 'B17041'},
#  {'A326', 'B22912'},
#  {'A327', 'B8016'},
#  {'A328', 'B13880'},
#  {'A329', 'B8941'},
#  {'A330', 'B11131'},
#  {'A331', 'B1779'},
#  {'A332', 'B12822'},
#  {'A333', 'B13931'},
#  {'A334', 'B24358'},
#  {'A335', 'B4562'},
#  {'A336', 'B2859'},
#  {'A337', 'B9911'},
#  {'A338', 'B2363'},
#  {'A339', 'B8076'},
#  {'A340', 'B1537'},
#  {'A341', 'B17154'},
#  {'A342', 'B17882'},
#  {'A343', 'B24239'},
#  {'A344', 'B10220'},
#  {'A345', 'B10477'},
#  {'A346', 'B20524'},
#  {'A347', 'B10556'},
#  {'A348', 'B23471'},
#  {'A349', 'B2988'},
#  {'A350', 'B10525'},
#  {'A351', 'B8429'},
#  {'A352', 'B17796'},
#  {'A353', 'B690'},
#  {'A354', 'B15176'},
#  {'A355', 'B11783'},
#  {'A356', 'B2050'},
#  {'A357', 'B4928'},
#  {'A358', 'B6043'},
#  {'A359', 'B2193'},
#  {'A360', 'B16366'},
#  {'A361', 'B15434'},
#  {'A362', 'B23216'},
#  {'A363', 'B7080'},
#  {'A364', 'B4000'},
#  {'A365', 'B3693'},
#  {'A366', 'B19853'},
#  {'A367', 'B12524'},
#  {'A368', 'B13697'},
#  {'A369', 'B13852'},
#  {'A370', 'B22736'},
#  {'A371', 'B23118'},
#  {'A372', 'B341'},
#  {'A373', 'B14328'},
#  {'A374', 'B2074'},
#  {'A375', 'B1443'},
#  {'A376', 'B1088'},
#  {'A377', 'B9026'},
#  {'A378', 'B4561'},
#  {'A379', 'B3008'},
#  {'A380', 'B12609'},
#  {'A381', 'B1301'},
#  {'A382', 'A383', 'B3229'},
#  {'A384', 'B8038'},
#  {'A385', 'B9230'},
#  {'A386', 'B17173'},
#  {'A387', 'B6708'},
#  {'A388', 'B6694'},
#  {'A389', 'B7566'},
#  {'A390', 'B8352'},
#  {'A391', 'B18684'},
#  {'A392', 'B15333'},
#  {'A393', 'B19722'},
#  {'A394', 'B16836'},
#  {'A395', 'A396', 'B24539'},
#  {'A397', 'A398', 'B23613'},
#  {'A399', 'B5355'},
#  {'A400', 'B5563'},
#  {'A401', 'B12264'},
#  {'A402', 'B17029'},
#  {'A403', 'B15787'},
#  {'A404', 'B1974'},
#  {'A405', 'B1167'},
#  {'A406', 'B8084'},
#  {'A407', 'B450'},
#  {'A408', 'B12888'},
#  {'A409', 'B1149'},
#  {'A410', 'B10164'},
#  {'A411', 'B9669'},
#  {'A412', 'A414', 'B21733'},
#  {'A413', 'B17225'},
#  {'A415', 'B19601'},
#  {'A416', 'B6883'},
#  {'A417', 'B480'},
#  {'A418', 'B9209'},
#  {'A419', 'B8751'},
#  {'A420', 'B16173'},
#  {'A421', 'B19605'},
#  {'A422', 'B4416'},
#  {'A423', 'B15605'},
#  {'A424', 'B7025'},
#  {'A425', 'B4329'},
#  {'A426', 'A428', 'B70'},
#  {'A429', 'B12480'},
#  {'A430', 'A431', 'B13058'},
#  {'A432', 'B21233'},
#  {'A433', 'B19810'},
#  {'A434', 'B22813'},
#  {'A435', 'B21016'},
#  {'A436', 'B618'},
#  {'A437', 'B5816'},
#  {'A438', 'B8034'},
#  {'A439', 'B8855'},
#  {'A440', 'B17371'},
#  {'A441', 'B18964'},
#  {'A442', 'B13417'},
#  {'A443', 'B14852'},
#  {'A444', 'B23169'},
#  {'A445', 'B22505'},
#  {'A446', 'B11787'},
#  {'A447', 'B14466'},
#  {'A448', 'B14359'},
#  {'A449', 'B23784'},
#  {'A450', 'B20662'},
#  {'A451', 'B20852'},
#  {'A452', 'B23308'},
#  {'A453', 'B4133'},
#  {'A454', 'B2255'},
#  {'A455', 'B2034'},
#  {'A456', 'A457', 'B2528'},
#  {'A458', 'B16361'},
#  {'A459', 'B199'},
#  {'A460', 'B10803'},
#  {'A461', 'B11166'},
#  {'A462', 'B20067'},
#  {'A463', 'B19288'},
#  {'A464', 'B13520'},
#  {'A465', 'B6654'},
#  {'A466', 'B7710'},
#  {'A467', 'B14742'},
#  {'A468', 'B18909'},
#  {'A469', 'B14808'},
#  {'A470', 'B4110'},
#  {'A471', 'B18728'},
#  {'A472', 'B19778'},
#  {'A473', 'B4290'},
#  {'A474', 'B777'},
#  {'A475', 'B9043'},
#  {'A476', 'B8991'},
#  {'A477', 'A478', 'B18541'},
#  {'A479', 'B6151'},
#  {'A480', 'B7565'},
#  {'A481', 'B15632'},
#  {'A482', 'B19320'},
#  {'A483', 'B12507'},
#  {'A485', 'B10019'},
#  {'A486', 'B11194'},
#  {'A487', 'B20711'},
#  {'A488', 'B20413'},
#  {'A489', 'B19106'},
#  {'A490', 'B3002'},
#  {'A491', 'B16663'},
#  {'A492', 'B16167'},
#  {'A493', 'B24257'},
#  {'A494', 'B21991'},
#  {'A495', 'B2713'},
#  {'A496', 'B2311'},
#  {'A497', 'B11099'},
#  {'A498', 'B4719'},
#  {'A499', 'B18681'},
#  {'A500', 'B4603'},
#  {'A501', 'B22554'},
#  {'A502', 'B9908'},
#  {'A503', 'B20274'},
#  {'A504', 'B12372'},
#  {'A505', 'B8432'},
#  {'A506', 'B24247'},
#  {'A507', 'B14221'},
#  {'A508', 'B14702'},
#  {'A509', 'B23558'},
#  {'A510', 'B7893'},
#  {'A511', 'B15748'},
#  {'A512', 'B15296'},
#  {'A513', 'B24215'},
#  {'A514', 'B21348'},
#  {'A515', 'B22078'},
#  {'A516', 'B3542'},
#  {'A517', 'B17125'},
#  {'A518', 'B12319'},
#  {'A519', 'B13401'},
#  {'A520', 'B20351'},
#  {'A521', 'B20814'},
#  {'A522', 'B22433'},
#  {'A523', 'B1719'},
#  {'A524', 'A586', 'B9895'},
#  {'A525', 'A526', 'B16571'},
#  {'A527', 'B23371'},
#  {'A528', 'B6334'},
#  {'A529', 'B11795'},
#  {'A531', 'B8611'},
#  {'A532', 'B15716'},
#  {'A533', 'B20397'},
#  {'A534', 'B14403'},
#  {'A535', 'B6420'},
#  {'A536', 'B17141'},
#  {'A537', 'B18596'},
#  {'A538', 'B24175'},
#  {'A539', 'B24302'},
#  {'A540', 'B10047'},
#  {'A541', 'B11524'},
#  {'A542', 'B23210'},
#  {'A543', 'B6485'},
#  {'A544', 'B7509'},
#  {'A545', 'B17636'},
#  {'A546', 'B16726'},
#  {'A547', 'B10172'},
#  {'A548', 'B155'},
#  {'A549', 'B18554'},
#  {'A550', 'B20503'},
#  {'A551', 'A552', 'B19891'},
#  {'A553', 'B4313'},
#  {'A554', 'B899'},
#  {'A555', 'B510'},
#  {'A556', 'B6549'},
#  {'A557', 'B7470'},
#  {'A558', 'B18707'},
#  {'A559', 'B9017'},
#  {'A560', 'B9051'},
#  {'A561', 'A562', 'B19447'},
#  {'A563', 'B972'},
#  {'A564', 'B14386'},
#  {'A565', 'B15295'},
#  {'A566', 'B22375'},
#  {'A567', 'B7137'},
#  {'A568', 'B15272'},
#  {'A569', 'B14527'},
#  {'A570', 'B24454'},
#  {'A571', 'B21339'},
#  {'A572', 'B24081'},
#  {'A573', 'B1452'},
#  {'A574', 'B12567'},
#  {'A575', 'B11863'},
#  {'A576', 'B2921'},
#  {'A577', 'B712'},
#  {'A578', 'B6365'},
#  {'A579', 'B15144'},
#  {'A580', 'B16212'},
#  {'A581', 'B24192'},
#  {'A582', 'B22213'},
#  {'A583', 'B1484'},
#  {'A584', 'B2278'},
#  {'A585', 'B13012'},
#  {'A587', 'B24299'},
#  {'A588', 'B4629'},
#  {'A589', 'B354'},
#  {'A590', 'A593', 'B22643'},
#  {'A591', 'B22419'},
#  {'A592', 'B24455'},
#  {'A594', 'B2245'},
#  {'A595', 'B11348'},
#  {'A596', 'B12893'},
#  {'A597', 'B2875'},
#  {'A598', 'B4277'},
#  {'A599', 'B15299'},
#  {'A600', 'B1592'},
#  {'A601', 'A603', 'B15674'},
#  {'A602', 'B8204'},
#  {'A604', 'B6504'},
#  {'A605', 'B20957'},
#  {'A606', 'B6210'},
#  {'A607', 'B6979'},
#  {'A608', 'B15010'},
#  {'A609', 'B19336'},
#  {'A610', 'B14740'},
#  {'A611', 'B10431'},
#  {'A612', 'B10589'},
#  {'A613', 'B18121'},
#  {'A614', 'B6833'},
#  {'A615', 'B4501'},
#  {'A616', 'B21790'},
#  {'A617', 'B20822'},
#  {'A618', 'B15111'},
#  {'A619', 'B7995'},
#  {'A620', 'B9919'},
#  {'A621', 'B20136'},
#  {'A622', 'B12257'},
#  {'A623', 'B3584'},
#  {'A624', 'B1963'},
#  {'A625', 'B14370'},
#  {'A626', 'A627', 'B4532'},
#  {'A628', 'B17436'},
#  {'A629', 'B6926'},
#  {'A630', 'B6220'},
#  {'A631', 'B10150'},
#  {'A632', 'B11017'},
#  {'A633', 'B18842'},
#  {'A634', 'B19830'},
#  {'A635', 'B18817'},
#  {'A636', 'B20343'},
#  {'A637', 'A638', 'B1240'},
#  {'A639', 'B16283'},
#  {'A640', 'B24129'},
#  {'A641', 'A642', 'B9551'},
#  {'A643', 'B21499'},
#  {'A644', 'B18391'},
#  {'A645', 'B20637'},
#  {'A646', 'B5695'},
#  {'A647', 'B6745'},
#  {'A648', 'B19902'},
#  {'A649', 'B3488'},
#  {'A650', 'B1800'},
#  {'A651', 'B24587'},
#  {'A652', 'B10163'},
#  {'A653', 'B22674'},
#  {'A654', 'B13754'},
#  {'A655', 'B7197'},
#  {'A656', 'B17240'},
#  {'A657', 'A659', 'B22574'},
#  {'A658', 'B8425'},
#  {'A660', 'B6257'},
#  {'A661', 'B3875'},
#  {'A662', 'B4806'},
#  {'A663', 'B17062'},
#  {'A664', 'B2515'},
#  {'A665', 'B2691'},
#  {'A666', 'B6657'},
#  {'A667', 'B4415'},
#  {'A668', 'B21220'},
#  {'A669', 'B8210'},
#  {'A670', 'B7489'},
#  {'A671', 'B3474'},
#  {'A672', 'B11717'},
#  {'A673', 'B10191'},
#  {'A674', 'B8943'},
#  {'A675', 'B8303'},
#  {'A676', 'B18484'},
#  {'A677', 'B12823'},
#  {'A678', 'B13183'},
#  {'A679', 'B24589'},
#  {'A680', 'B15510'},
#  {'A681', 'B16785'},
#  {'A682', 'B22884'},
#  {'A683', 'B24485'},
#  {'A684', 'B1141'},
#  {'A685', 'A787', 'B18794'},
#  {'A686', 'B5174'},
#  {'A687', 'B5223'},
#  {'A688', 'B17771'},
#  {'A689', 'B4777'},
#  {'A690', 'B1267'},
#  {'A691', 'B7952'},
#  {'A692', 'B1696'},
#  {'A693', 'B12725'},
#  {'A694', 'B17863'},
#  {'A695', 'B931'},
#  {'A696', 'A734', 'B2967'},
#  {'A697', 'A741', 'B16550'},
#  {'A698', 'B15670'},
#  {'A699', 'B24471'},
#  {'A700', 'B22765'},
#  {'A701', 'B11708'},
#  {'A702', 'B12240'},
#  {'A703', 'B24040'},
#  {'A704', 'B22619'},
#  {'A705', 'B6202'},
#  {'A706', 'B6428'},
#  {'A707', 'B10935'},
#  {'A708', 'B10173'},
#  {'A709', 'B10010'},
#  {'A710', 'B19621'},
#  {'A711', 'B22921'},
#  {'A712', 'B16678'},
#  {'A713', 'B17299'},
#  {'A714', 'B23312'},
#  {'A715', 'B24285'},
#  {'A716', 'B3534'},
#  {'A717', 'B1809'},
#  {'A718', 'B2068'},
#  {'A719', 'B82'},
#  {'A720', 'B16809'},
#  {'A721', 'B16507'},
#  {'A722', 'B6928'},
#  {'A723', 'B15474'},
#  {'A724', 'B15586'},
#  {'A725', 'A726', 'B22860'},
#  {'A727', 'B14715'},
#  {'A728', 'B9379'},
#  {'A729', 'B5143'},
#  {'A730', 'B12813'},
#  {'A731', 'B6469'},
#  {'A732', 'B4448'},
#  {'A733', 'B3271'},
#  {'A735', 'B2837'},
#  {'A736', 'B12878'},
#  {'A737', 'B12659'},
#  {'A738', 'B24002'},
#  {'A739', 'B12691'},
#  {'A740', 'B16782'},
#  {'A742', 'B18138'},
#  {'A743', 'B18680'},
#  {'A744', 'A745', 'B18463'},
#  {'A746', 'B6189'},
#  {'A747', 'B10362'},
#  {'A748', 'B11295'},
#  {'A749', 'B19304'},
#  {'A750', 'B19027'},
#  {'A751', 'B19826'},
#  {'A752', 'B2985'},
#  {'A753', 'B22410'},
#  {'A754', 'B19068'},
#  {'A755', 'B7408'},
#  {'A756', 'B7524'},
#  {'A757', 'B18973'},
#  {'A758', 'B2444'},
#  {'A759', 'B24463'},
#  {'A760', 'B15112'},
#  {'A761', 'B2344'},
#  {'A762', 'B1058'},
#  {'A763', 'B9801'},
#  {'A764', 'B173'},
#  {'A765', 'B16519'},
#  {'A766', 'B318'},
#  {'A767', 'B7668'},
#  {'A768', 'B8035'},
#  {'A769', 'B20829'},
#  {'A770', 'B18379'},
#  {'A771', 'B18010'},
#  {'A772', 'B1889'},
#  {'A773', 'B5376'},
#  {'A774', 'B6243'},
#  {'A775', 'B24482'},
#  {'A776', 'B16516'},
#  {'A777', 'B3557'},
#  {'A778', 'B3970'},
#  {'A779', 'B2491'},
#  {'A780', 'B13450'},
#  {'A781', 'B15287'},
#  {'A782', 'B16174'},
#  {'A783', 'B21794'},
#  {'A784', 'B7029'},
#  {'A785', 'B7333'},
#  {'A786', 'B16168'},
#  {'A788', 'B17831'},
#  {'A789', 'A790', 'A791', 'B9482'},
#  {'A792', 'B20750'},
#  {'A793', 'B7615'},
#  {'A794', 'B6417'},
#  {'A795', 'B20642'},
#  {'A796', 'B20926'},
#  {'A797', 'A801', 'B11324'},
#  {'A798', 'B22529'},
#  {'A799', 'B16084'},
#  {'A800', 'B14194'},
#  {'A802', 'B1563'},
#  {'A803', 'B1073'},
#  {'A804', 'B5778'},
#  {'A805', 'B5719'},
#  {'A807', 'B5601'},
#  {'A808', 'B9981'},
#  {'A809', 'B10975'},
#  {'A810', 'B19647'},
#  {'A811', 'B23555'},
#  {'A812', 'B13800'},
#  {'A813', 'B14375'},
#  {'A814', 'B24343'},
#  {'A815', 'B12081'},
#  {'A816', 'B21401'},
#  {'A817', 'B10005'},
#  {'A818', 'B18070'},
#  {'A819', 'B5149'},
#  {'A820', 'B5527'},
#  {'A821', 'B13748'},
#  {'A822', 'B12131'},
#  {'A823', 'B1002'},
#  {'A824', 'A836', 'B4954'},
#  {'A825', 'B5610'},
#  {'A826', 'B6275'},
#  {'A827', 'B15191'},
#  {'A828', 'B5667'},
#  {'A829', 'B7859'},
#  {'A830', 'B5630'},
#  {'A831', 'B12008'},
#  {'A832', 'B11555'},
#  {'A833', 'B21640'},
#  {'A834', 'B5496'},
#  {'A835', 'B3761'},
#  {'A837', 'B5673'},
#  {'A838', 'A839', 'B13678'},
#  {'A840', 'B21428'},
#  {'A841', 'B10898'},
#  {'A842', 'B6636'},
#  {'A843', 'B1070'},
#  {'A844', 'B2185'},
#  {'A845', 'B9549'},
#  {'A846', 'B555'},
#  {'A847', 'B8339'},
#  {'A848', 'B14738'},
#  {'A849', 'B14752'},
#  {'A850', 'B23780'},
#  {'A851', 'B3127'},
#  {'A852', 'B13496'},
#  {'A853', 'B4069'},
#  {'A854', 'B4948'},
#  {'A855', 'B14934'},
#  {'A856', 'B14897'},
#  {'A857', 'B24156'},
#  {'A858', 'B24413'},
#  {'A859', 'B17632'},
#  {'A860', 'B693'},
#  {'A861', 'B12278'},
#  {'A862', 'B606'},
#  {'A863', 'A864', 'B23220'},
#  {'A865', 'B19305'},
#  {'A866', 'B15622'},
#  {'A867', 'B15626'},
#  {'A868', 'A885', 'B23896'},
#  {'A869', 'B23062'},
#  {'A870', 'B24571'},
#  {'A871', 'B17508'},
#  {'A872', 'B6867'},
#  {'A873', 'B11444'},
#  {'A874', 'B12696'},
#  {'A875', 'B21590'},
#  {'A876', 'B11718'},
#  {'A877', 'B7860'},
#  {'A878', 'B7958'},
#  {'A879', 'B15904'},
#  {'A880', 'B20025'},
#  {'A881', 'B17571'},
#  {'A882', 'B19460'},
#  {'A883', 'B7373'},
#  {'A884', 'B9298'},
#  {'A886', 'B4257'},
#  {'A887', 'A951', 'B8340'},
#  {'A888', 'B6698'},
#  {'A889', 'B6945'},
#  {'A890', 'B7365'},
#  {'A891', 'B16225'},
#  {'A892', 'B17116'},
#  {'A893', 'B16578'},
#  {'A894', 'B15449'},
#  {'A895', 'B13130'},
#  {'A896', 'B12722'},
#  {'A897', 'B21184'},
#  {'A898', 'B7490'},
#  {'A899', 'B5298'},
#  {'A900', 'B860'},
#  {'A901', 'B13430'},
#  {'A902', 'B14310'},
#  {'A903', 'B22089'},
#  {'A904', 'B4295'},
#  {'A905', 'B13177'},
#  {'A906', 'B682'},
#  {'A907', 'B991'},
#  {'A908', 'B16131'},
#  {'A909', 'B7129'},
#  {'A1020', 'A910', 'B4478'},
#  {'A911', 'B3062'},
#  {'A912', 'B4687'},
#  {'A913', 'B16213'},
#  {'A914', 'B15356'},
#  {'A915', 'B21745'},
#  {'A916', 'B16778'},
#  {'A917', 'B16367'},
#  {'A918', 'B22997'},
#  {'A919', 'B24044'},
#  {'A920', 'B22782'},
#  {'A921', 'B5295'},
#  {'A922', 'B6514'},
#  {'A923', 'B19118'},
#  {'A924', 'A925', 'B13153'},
#  {'A926', 'B9382'},
#  {'A927', 'B24452'},
#  {'A928', 'B17006'},
#  {'A929', 'B11665'},
#  {'A930', 'B11505'},
#  {'A931', 'B22436'},
#  {'A932', 'B21893'},
#  {'A933', 'B14796'},
#  {'A934', 'A942', 'B11567'},
#  {'A935', 'B21456'},
#  {'A936', 'B22587'},
#  {'A937', 'B22446'},
#  {'A938', 'B6750'},
#  {'A939', 'B6137'},
#  {'A940', 'B18526'},
#  {'A941', 'B13258'},
#  {'A943', 'B12281'},
#  {'A944', 'B10'},
#  {'A945', 'B23275'},
#  {'A946', 'B20080'},
#  {'A947', 'B14769'},
#  {'A948', 'B153'},
#  {'A949', 'B24384'},
#  {'A950', 'A996', 'B1826'},
#  {'A952', 'B7945'},
#  {'A953', 'B18683'},
#  {'A954', 'B17479'},
#  {'A955', 'A957', 'A958', 'B3903'},
#  {'A956', 'B12877'},
#  {'A959', 'B17538'},
#  {'A960', 'B2689'},
#  {'A961', 'B16288'},
#  {'A962', 'B23585'},
#  {'A963', 'B15463'},
#  {'A964', 'B15987'},
#  {'A965', 'B24100'},
#  {'A966', 'B22949'},
#  {'A967', 'B1820'},
#  {'A968', 'B3871'},
#  {'A969', 'B11337'},
#  {'A970', 'B4149'},
#  {'A971', 'B1304'},
#  {'A972', 'B2701'},
#  {'A973', 'B8961'},
#  {'A974', 'B9743'},
#  {'A975', 'B10226'},
#  {'A976', 'B22034'},
#  {'A977', 'B20784'},
#  {'A978', 'B9459'},
#  {'A979', 'B21748'},
#  {'A980', 'B19375'},
#  {'A981', 'B12381'},
#  {'A982', 'B15380'},
#  {'A983', 'B8361'},
#  {'A984', 'B19780'},
#  {'A985', 'B11765'},
#  {'A986', 'B20936'},
#  {'A987', 'B16557'},
#  {'A988', 'B1268'},
#  {'A989', 'B18589'},
#  {'A990', 'B7467'},
#  {'A991', 'B2926'},
#  {'A992', 'B14924'},
#  {'A993', 'B14442'},
#  {'A994', 'B23788'},
#  {'A995', 'B22586'},
#  {'A997', 'B10415'},
#  {'A998', 'B9936'},
#  {'A999', 'B9768'},
#  {'A1000', 'B18421'},
#  {'A1001', 'B18580'},
#  {'A1002', 'B5170'},
#  {'A1003', 'B6587'},
#  {'A1004', 'B18813'},
#  {'A1005', 'B15060'},
#  {'A1006', 'B2012'},
#  {'A1007', 'B1499'},
#  {'A1008', 'B7928'},
#  {'A1009', 'B2624'},
#  {'A1010', 'B2571'},
#  {'A1011', 'B22171'},
#  {'A1012', 'B9679'},
#  {'A1013', 'B2521'},
#  {'A1014', 'B6596'},
#  {'A1015', 'B4558'},
#  {'A1016', 'B17915'},
#  {'A1017', 'B24396'},
#  {'A1018', 'B20540'},
#  {'A1019', 'B23417'},
#  {'A1021', 'B8278'},
#  {'A1022', 'B638'},
#  {'A1023', 'B6342'},
#  {'A1024', 'B6810'},
#  {'A1025', 'A1026', 'B14943'},
#  {'A1027', 'B13285'},
#  {'A1028', 'B4760'},
#  {'A1029', 'B455'},
#  {'A1030', 'A1034', 'B23311'},
#  {'A1031', 'B16790'},
#  {'A1032', 'B22562'},
#  {'A1033', 'B22414'},
#  {'A1035', 'B13757'},
#  {'A1036', 'B3035'},
#  {'A1037', 'B23088'},
#  {'A1038', 'B14761'},
#  {'A1039', 'B10623'},
#  {'A1040', 'B14668'},
#  {'A1041', 'B33'},
#  {'A1042', 'B23179'},
#  {'A1043', 'B12346'},
#  {'A1044', 'B13793'},
#  {'A1045', 'B21519'},
#  {'A1046', 'B6244'},
#  {'A1047', 'B23708'},
#  {'A1048', 'B2462'},
#  {'A1049', 'B17476'},
#  {'A1050', 'B4413'},
#  {'A1051', 'B1302'},
#  {'A1052', 'B2022'},
#  {'A1053', 'B12536'},
#  {'A1054', 'B15528'},
#  {'A1055', 'B14886'},
#  {'A1056', 'B24149'},
#  {'A1057', 'B21100'},
#  {'A1058', 'B11697'},
#  {'A1059', 'A1075', 'B69'},
#  {'A1060', 'B4997'},
#  {'A1061', 'B7664'},
#  {'A1062', 'B12192'},
#  {'A1063', 'B13178'},
#  {'A1064', 'B19820'},
#  {'A1065', 'B20349'},
#  {'A1066', 'B22662'},
#  {'A1067', 'B20332'},
#  {'A1068', 'B243'},
#  ...]

# %%
#modyfikujemy wartości w pliku tp do formatu A1, A2, B1, B2 itd
tp['index_census'] = tp['index_census'].apply(lambda x: f'A{x}')
tp['index_cis'] = tp['index_cis'].apply(lambda y: f'B{y}')
# Out:
# <ipython-input-29-2f40fa59ea3e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tp['index_census'] = tp['index_census'].apply(lambda x: f'A{x}')
# <ipython-input-29-2f40fa59ea3e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tp['index_cis'] = tp['index_cis'].apply(lambda y: f'B{y}')

# %%
tp
# Out:
#     index_census index_cis      Distance
# 0            A19    B21255  3.576279e-07
# 1            A34     B9523  1.489362e-01
# 2            A43     B6753  8.228964e-02
# 3            A80    B17311  6.794083e-02
# 4            A97    B12385  1.043311e-01
# ..           ...       ...           ...
# 966       A25277    B16237  0.000000e+00
# 967       A25283    B10250  4.444444e-02
# 968       A25308    B15945  4.878080e-02
# 969       A25318     B6675  8.888888e-02
# 970       A25322    B14776  3.576279e-07
#
# [971 rows x 3 columns]

# %%
#filtrujemy zbiór df w celu zachowania jedynie par, których indeksy dla pliku census pojawiają się w pliku tp (na potrzeby testu jakości)
tp_ids = tp['index_census'].unique()

# Filtruj DataFrame census, aby zachować tylko te rekordy, których 'id' znajduje się w tp_ids
filtered_pairs = df[df['index_census'].isin(tp_ids)]



tp_ids
# Out:
# array(['A19', 'A34', 'A43', 'A80', 'A97', 'A125', 'A133', 'A185', 'A203',
#        'A207', 'A232', 'A252', 'A289', 'A337', 'A364', 'A372', 'A373',
#        'A391', 'A402', 'A438', 'A451', 'A514', 'A515', 'A548', 'A553',
#        'A554', 'A598', 'A703', 'A714', 'A757', 'A786', 'A794', 'A812',
#        'A858', 'A866', 'A869', 'A881', 'A961', 'A978', 'A994', 'A1026',
#        'A1034', 'A1056', 'A1075', 'A1076', 'A1091', 'A1130', 'A1137',
#        'A1198', 'A1260', 'A1340', 'A1380', 'A1400', 'A1415', 'A1446',
#        'A1515', 'A1541', 'A1555', 'A1577', 'A1597', 'A1601', 'A1626',
#        'A1629', 'A1649', 'A1673', 'A1721', 'A1741', 'A1742', 'A1744',
#        'A1787', 'A1813', 'A1842', 'A1862', 'A1903', 'A1910', 'A1962',
#        'A1969', 'A1978', 'A1980', 'A2018', 'A2031', 'A2061', 'A2071',
#        'A2177', 'A2206', 'A2287', 'A2298', 'A2343', 'A2360', 'A2409',
#        'A2439', 'A2463', 'A2483', 'A2496', 'A2564', 'A2575', 'A2587',
#        'A2621', 'A2632', 'A2652', 'A2667', 'A2719', 'A2739', 'A2741',
#        'A2830', 'A2836', 'A2852', 'A2881', 'A2889', 'A2911', 'A2993',
#        'A2994', 'A2996', 'A3078', 'A3085', 'A3126', 'A3181', 'A3185',
#        'A3293', 'A3299', 'A3312', 'A3329', 'A3333', 'A3335', 'A3346',
#        'A3354', 'A3357', 'A3358', 'A3427', 'A3431', 'A3514', 'A3525',
#        'A3526', 'A3550', 'A3554', 'A3595', 'A3616', 'A3642', 'A3650',
#        'A3670', 'A3682', 'A3684', 'A3748', 'A3753', 'A3783', 'A3808',
#        'A3814', 'A3824', 'A3832', 'A3867', 'A3899', 'A3910', 'A3914',
#        'A3918', 'A3945', 'A3961', 'A4037', 'A4057', 'A4063', 'A4086',
#        'A4129', 'A4133', 'A4136', 'A4241', 'A4258', 'A4287', 'A4328',
#        'A4370', 'A4379', 'A4385', 'A4389', 'A4391', 'A4399', 'A4449',
#        'A4481', 'A4502', 'A4553', 'A4556', 'A4578', 'A4666', 'A4688',
#        'A4709', 'A4737', 'A4751', 'A4788', 'A4793', 'A4809', 'A4830',
#        'A4838', 'A4879', 'A4890', 'A4895', 'A4898', 'A4903', 'A4927',
#        'A4941', 'A4990', 'A4997', 'A5002', 'A5056', 'A5081', 'A5088',
#        'A5105', 'A5113', 'A5123', 'A5198', 'A5204', 'A5259', 'A5353',
#        'A5398', 'A5427', 'A5473', 'A5478', 'A5505', 'A5507', 'A5525',
#        'A5606', 'A5643', 'A5689', 'A5701', 'A5707', 'A5724', 'A5771',
#        'A5787', 'A5815', 'A5871', 'A5917', 'A5934', 'A6025', 'A6028',
#        'A6044', 'A6058', 'A6065', 'A6103', 'A6104', 'A6111', 'A6127',
#        'A6149', 'A6153', 'A6169', 'A6199', 'A6225', 'A6271', 'A6274',
#        'A6289', 'A6294', 'A6315', 'A6331', 'A6371', 'A6376', 'A6403',
#        'A6425', 'A6441', 'A6470', 'A6489', 'A6504', 'A6545', 'A6569',
#        'A6571', 'A6591', 'A6594', 'A6612', 'A6616', 'A6626', 'A6632',
#        'A6666', 'A6750', 'A6756', 'A6769', 'A6791', 'A6847', 'A6850',
#        'A6852', 'A6931', 'A6944', 'A6957', 'A6970', 'A6972', 'A7010',
#        'A7017', 'A7060', 'A7062', 'A7075', 'A7126', 'A7143', 'A7241',
#        'A7246', 'A7296', 'A7305', 'A7379', 'A7391', 'A7400', 'A7452',
#        'A7471', 'A7476', 'A7497', 'A7504', 'A7549', 'A7560', 'A7594',
#        'A7625', 'A7637', 'A7673', 'A7680', 'A7729', 'A7776', 'A7787',
#        'A7841', 'A7897', 'A7928', 'A7934', 'A7955', 'A7997', 'A8001',
#        'A8022', 'A8036', 'A8067', 'A8088', 'A8141', 'A8143', 'A8162',
#        'A8166', 'A8214', 'A8241', 'A8268', 'A8275', 'A8280', 'A8317',
#        'A8401', 'A8428', 'A8485', 'A8505', 'A8568', 'A8585', 'A8653',
#        'A8658', 'A8673', 'A8676', 'A8717', 'A8751', 'A8761', 'A8812',
#        'A8813', 'A8814', 'A8817', 'A8829', 'A8844', 'A8883', 'A8932',
#        'A8933', 'A8950', 'A8959', 'A9000', 'A9020', 'A9022', 'A9031',
#        'A9050', 'A9071', 'A9077', 'A9097', 'A9108', 'A9118', 'A9184',
#        'A9188', 'A9228', 'A9231', 'A9284', 'A9314', 'A9381', 'A9386',
#        'A9433', 'A9624', 'A9765', 'A9771', 'A9821', 'A9837', 'A9872',
#        'A9875', 'A9901', 'A9930', 'A9937', 'A9950', 'A9957', 'A9963',
#        'A9987', 'A10017', 'A10055', 'A10059', 'A10081', 'A10165',
#        'A10166', 'A10197', 'A10199', 'A10251', 'A10255', 'A10267',
#        'A10356', 'A10380', 'A10387', 'A10442', 'A10455', 'A10496',
#        'A10499', 'A10551', 'A10563', 'A10567', 'A10629', 'A10663',
#        'A10677', 'A10748', 'A10810', 'A10820', 'A10840', 'A10850',
#        'A10930', 'A11016', 'A11046', 'A11100', 'A11105', 'A11136',
#        'A11168', 'A11204', 'A11225', 'A11236', 'A11240', 'A11258',
#        'A11335', 'A11336', 'A11343', 'A11347', 'A11406', 'A11435',
#        'A11481', 'A11490', 'A11509', 'A11516', 'A11533', 'A11542',
#        'A11555', 'A11572', 'A11596', 'A11601', 'A11650', 'A11680',
#        'A11685', 'A11692', 'A11753', 'A11773', 'A11868', 'A11888',
#        'A11915', 'A11962', 'A11965', 'A11974', 'A12026', 'A12033',
#        'A12050', 'A12114', 'A12121', 'A12146', 'A12200', 'A12214',
#        'A12220', 'A12229', 'A12252', 'A12256', 'A12276', 'A12353',
#        'A12435', 'A12436', 'A12472', 'A12483', 'A12490', 'A12493',
#        'A12521', 'A12528', 'A12561', 'A12585', 'A12594', 'A12618',
#        'A12655', 'A12657', 'A12668', 'A12731', 'A12734', 'A12748',
#        'A12750', 'A12831', 'A12849', 'A12882', 'A12895', 'A12933',
#        'A12937', 'A12958', 'A13018', 'A13022', 'A13055', 'A13173',
#        'A13176', 'A13181', 'A13191', 'A13193', 'A13206', 'A13235',
#        'A13257', 'A13267', 'A13279', 'A13295', 'A13302', 'A13319',
#        'A13322', 'A13364', 'A13392', 'A13407', 'A13436', 'A13579',
#        'A13594', 'A13633', 'A13661', 'A13795', 'A13800', 'A13835',
#        'A13956', 'A13959', 'A13969', 'A13995', 'A14006', 'A14020',
#        'A14025', 'A14063', 'A14103', 'A14107', 'A14122', 'A14160',
#        'A14168', 'A14230', 'A14238', 'A14249', 'A14270', 'A14275',
#        'A14280', 'A14331', 'A14349', 'A14362', 'A14373', 'A14379',
#        'A14412', 'A14428', 'A14449', 'A14474', 'A14501', 'A14503',
#        'A14508', 'A14529', 'A14550', 'A14573', 'A14609', 'A14675',
#        'A14700', 'A14719', 'A14725', 'A14729', 'A14764', 'A14809',
#        'A14829', 'A14871', 'A14899', 'A14909', 'A14914', 'A14915',
#        'A14946', 'A14958', 'A14988', 'A15012', 'A15015', 'A15039',
#        'A15063', 'A15072', 'A15074', 'A15076', 'A15105', 'A15111',
#        'A15156', 'A15159', 'A15169', 'A15180', 'A15184', 'A15189',
#        'A15222', 'A15284', 'A15309', 'A15365', 'A15495', 'A15536',
#        'A15554', 'A15570', 'A15620', 'A15636', 'A15641', 'A15646',
#        'A15651', 'A15678', 'A15698', 'A15766', 'A15830', 'A15851',
#        'A15859', 'A15907', 'A15941', 'A15966', 'A15983', 'A16000',
#        'A16028', 'A16091', 'A16183', 'A16287', 'A16304', 'A16336',
#        'A16352', 'A16358', 'A16373', 'A16413', 'A16423', 'A16466',
#        'A16475', 'A16486', 'A16487', 'A16502', 'A16545', 'A16587',
#        'A16748', 'A16803', 'A16809', 'A16904', 'A16930', 'A16962',
#        'A16964', 'A16990', 'A17008', 'A17028', 'A17031', 'A17034',
#        'A17039', 'A17056', 'A17084', 'A17094', 'A17163', 'A17174',
#        'A17191', 'A17194', 'A17212', 'A17216', 'A17259', 'A17286',
#        'A17315', 'A17330', 'A17338', 'A17355', 'A17454', 'A17455',
#        'A17482', 'A17505', 'A17512', 'A17581', 'A17593', 'A17626',
#        'A17629', 'A17630', 'A17741', 'A17750', 'A17791', 'A17794',
#        'A17825', 'A17834', 'A17845', 'A17869', 'A17887', 'A17921',
#        'A17952', 'A18003', 'A18005', 'A18084', 'A18137', 'A18138',
#        'A18141', 'A18164', 'A18200', 'A18207', 'A18216', 'A18235',
#        'A18268', 'A18291', 'A18336', 'A18399', 'A18576', 'A18616',
#        'A18637', 'A18670', 'A18707', 'A18727', 'A18732', 'A18748',
#        'A18770', 'A18783', 'A18795', 'A18830', 'A18839', 'A18852',
#        'A18859', 'A18892', 'A18921', 'A18945', 'A18946', 'A18994',
#        'A19028', 'A19061', 'A19074', 'A19082', 'A19103', 'A19112',
#        'A19133', 'A19191', 'A19235', 'A19240', 'A19242', 'A19253',
#        'A19279', 'A19292', 'A19308', 'A19348', 'A19350', 'A19375',
#        'A19387', 'A19388', 'A19398', 'A19447', 'A19450', 'A19481',
#        'A19487', 'A19489', 'A19511', 'A19537', 'A19550', 'A19572',
#        'A19587', 'A19717', 'A19725', 'A19737', 'A19743', 'A19766',
#        'A19824', 'A19928', 'A19960', 'A19970', 'A19993', 'A20015',
#        'A20019', 'A20036', 'A20078', 'A20085', 'A20100', 'A20110',
#        'A20160', 'A20212', 'A20235', 'A20251', 'A20258', 'A20260',
#        'A20319', 'A20337', 'A20346', 'A20361', 'A20365', 'A20368',
#        'A20370', 'A20371', 'A20372', 'A20375', 'A20403', 'A20412',
#        'A20426', 'A20453', 'A20509', 'A20522', 'A20543', 'A20554',
#        'A20562', 'A20567', 'A20600', 'A20606', 'A20621', 'A20638',
#        'A20676', 'A20741', 'A20795', 'A20818', 'A20832', 'A20835',
#        'A20840', 'A20846', 'A20870', 'A20890', 'A20941', 'A20990',
#        'A21040', 'A21059', 'A21075', 'A21090', 'A21094', 'A21120',
#        'A21129', 'A21131', 'A21159', 'A21163', 'A21200', 'A21203',
#        'A21208', 'A21222', 'A21256', 'A21259', 'A21273', 'A21349',
#        'A21396', 'A21450', 'A21452', 'A21534', 'A21536', 'A21543',
#        'A21566', 'A21579', 'A21622', 'A21651', 'A21656', 'A21675',
#        'A21679', 'A21688', 'A21690', 'A21708', 'A21778', 'A21812',
#        'A21818', 'A21823', 'A21841', 'A21855', 'A21950', 'A21960',
#        'A21962', 'A21972', 'A21996', 'A22049', 'A22071', 'A22074',
#        'A22109', 'A22119', 'A22157', 'A22208', 'A22212', 'A22263',
#        'A22269', 'A22313', 'A22331', 'A22348', 'A22365', 'A22375',
#        'A22402', 'A22424', 'A22448', 'A22543', 'A22588', 'A22617',
#        'A22641', 'A22698', 'A22711', 'A22765', 'A22868', 'A22913',
#        'A22917', 'A22931', 'A22943', 'A22951', 'A22953', 'A23008',
#        'A23038', 'A23054', 'A23079', 'A23096', 'A23107', 'A23118',
#        'A23133', 'A23134', 'A23160', 'A23203', 'A23259', 'A23267',
#        'A23273', 'A23297', 'A23353', 'A23384', 'A23387', 'A23389',
#        'A23474', 'A23534', 'A23617', 'A23626', 'A23641', 'A23659',
#        'A23669', 'A23756', 'A23776', 'A23839', 'A23860', 'A23885',
#        'A23896', 'A23899', 'A23905', 'A23912', 'A23926', 'A23953',
#        'A24025', 'A24044', 'A24057', 'A24060', 'A24065', 'A24103',
#        'A24147', 'A24157', 'A24163', 'A24166', 'A24171', 'A24208',
#        'A24222', 'A24284', 'A24320', 'A24415', 'A24476', 'A24485',
#        'A24565', 'A24623', 'A24647', 'A24685', 'A24737', 'A24742',
#        'A24774', 'A24783', 'A24845', 'A24859', 'A24875', 'A24880',
#        'A24915', 'A24918', 'A24938', 'A24951', 'A25028', 'A25068',
#        'A25085', 'A25094', 'A25118', 'A25122', 'A25137', 'A25151',
#        'A25168', 'A25183', 'A25217', 'A25237', 'A25243', 'A25252',
#        'A25277', 'A25283', 'A25308', 'A25318', 'A25322'], dtype=object)

# %%
len(tp_ids)
# Out:
# 971

# %%
#tworzymy graf zgodnie z dopasowaniami
G = nx.Graph()

# Dodaj węzły z obu zbiorów danych
for i in range(len(census)):
    G.add_node(f'A{i}', record=census.iloc[i])

for j in range(len(cis)):
    G.add_node(f'B{j}', record=cis.iloc[j])

# Dodaj krawędzie na podstawie najbliższych sąsiadów
for _, row in filtered_pairs.iterrows():
    G.add_edges_from([(row["index_census"], row["index_cis"])])

# %%
#tworzymy i wyświetlamy listę klastrów
clusterspp = list(nx.connected_components(G))
clusterspp = [component for component in nx.connected_components(G) if len(component) > 1]



# Wyświetlenie informacji o klastrach
#print(f"Liczba klastrów: {len(clusterspp)}")
#for i, cluster in enumerate(clusterspp):
#    print(f"Klaster {i+1}: {cluster}")

# %%
clusterspp
# Out:
# [{'A19', 'B21255'},
#  {'A34', 'B9523'},
#  {'A43', 'B6753'},
#  {'A80', 'B17311'},
#  {'A97', 'B12385'},
#  {'A125', 'B11308'},
#  {'A133', 'B8237'},
#  {'A185', 'B16414'},
#  {'A203', 'B404'},
#  {'A207', 'B1982'},
#  {'A232', 'B14635'},
#  {'A252', 'B7606'},
#  {'A289', 'B11063'},
#  {'A337', 'B9911'},
#  {'A364', 'B4000'},
#  {'A372', 'B341'},
#  {'A373', 'B14328'},
#  {'A391', 'B18684'},
#  {'A402', 'B17029'},
#  {'A438', 'B8034'},
#  {'A451', 'B20852'},
#  {'A514', 'B21348'},
#  {'A515', 'B22078'},
#  {'A548', 'B155'},
#  {'A553', 'B4313'},
#  {'A554', 'B899'},
#  {'A598', 'B4277'},
#  {'A703', 'B24040'},
#  {'A714', 'B23312'},
#  {'A757', 'B18973'},
#  {'A786', 'B16168'},
#  {'A794', 'B6417'},
#  {'A812', 'B13800'},
#  {'A858', 'B24413'},
#  {'A866', 'B15622'},
#  {'A869', 'B23062'},
#  {'A881', 'B17571'},
#  {'A961', 'B16288'},
#  {'A978', 'B9459'},
#  {'A994', 'B23788'},
#  {'A1026', 'B14943'},
#  {'A1034', 'B23311'},
#  {'A1056', 'B24149'},
#  {'A1075', 'B69'},
#  {'A1076', 'B7609'},
#  {'A1091', 'B12459'},
#  {'A1130', 'B11070'},
#  {'A1137', 'B984'},
#  {'A1198', 'B13317'},
#  {'A1260', 'B18949'},
#  {'A1340', 'B1079'},
#  {'A1380', 'B22387'},
#  {'A1400', 'B17080'},
#  {'A1415', 'B15195'},
#  {'A1446', 'B17546'},
#  {'A1515', 'B9620'},
#  {'A1541', 'B14389'},
#  {'A1555', 'B7047'},
#  {'A1577', 'B21045'},
#  {'A1597', 'B17850'},
#  {'A1601', 'B10240'},
#  {'A1626', 'B922'},
#  {'A1629', 'B11981'},
#  {'A1649', 'B3387'},
#  {'A1673', 'B5385'},
#  {'A1721', 'B6913'},
#  {'A1741', 'B10276'},
#  {'A1742', 'B21505'},
#  {'A1744', 'B3559'},
#  {'A1787', 'B14298'},
#  {'A1813', 'B13892'},
#  {'A1842', 'B21554'},
#  {'A1862', 'B1191'},
#  {'A1903', 'B21736'},
#  {'A1910', 'B22421'},
#  {'A1962', 'B4702'},
#  {'A1969', 'B2642'},
#  {'A1978', 'B12606'},
#  {'A1980', 'B9841'},
#  {'A2018', 'B7153'},
#  {'A2031', 'B4039'},
#  {'A2061', 'B21559'},
#  {'A2071', 'B11343'},
#  {'A2177', 'B6476'},
#  {'A2206', 'B1431'},
#  {'A2287', 'B13366'},
#  {'A2298', 'B8195'},
#  {'A2343', 'B24394'},
#  {'A2360', 'B12727'},
#  {'A2409', 'B10113'},
#  {'A2439', 'B12945'},
#  {'A2463', 'B20509'},
#  {'A2483', 'B16341'},
#  {'A2496', 'B14116'},
#  {'A2564', 'B10760'},
#  {'A2575', 'B5549'},
#  {'A2587', 'B15642'},
#  {'A2621', 'B7592'},
#  {'A2632', 'B3818'},
#  {'A2652', 'B18228'},
#  {'A2667', 'B2812'},
#  {'A2719', 'B17999'},
#  {'A2739', 'B15968'},
#  {'A2741', 'B20234'},
#  {'A2830', 'B23877'},
#  {'A2836', 'B13618'},
#  {'A2852', 'B22088'},
#  {'A2881', 'B5769'},
#  {'A2889', 'B21067'},
#  {'A2911', 'B16342'},
#  {'A2993', 'B5767'},
#  {'A2994', 'B5645'},
#  {'A2996', 'B13240'},
#  {'A3078', 'B115'},
#  {'A3085', 'B15077'},
#  {'A3126', 'B18809'},
#  {'A3181', 'B18210'},
#  {'A3185', 'B13676'},
#  {'A3293', 'B22266'},
#  {'A3299', 'B3054'},
#  {'A3312', 'B8423'},
#  {'A3329', 'B5069'},
#  {'A3333', 'B7965'},
#  {'A3335', 'B2060'},
#  {'A3346', 'B24403'},
#  {'A3354', 'B5543'},
#  {'A3357', 'B23929'},
#  {'A3358', 'B20578'},
#  {'A3427', 'B512'},
#  {'A3431', 'B13230'},
#  {'A3514', 'B13572'},
#  {'A3525', 'B12620'},
#  {'A3526', 'B20898'},
#  {'A3550', 'B20543'},
#  {'A3554', 'B10249'},
#  {'A3595', 'B4507'},
#  {'A3616', 'B8142'},
#  {'A3642', 'B24026'},
#  {'A3650', 'B19984'},
#  {'A3670', 'B22791'},
#  {'A3682', 'B1551'},
#  {'A3684', 'B7857'},
#  {'A3748', 'B12985'},
#  {'A3753', 'B15559'},
#  {'A3783', 'B21741'},
#  {'A3808', 'B3920'},
#  {'A3814', 'B15057'},
#  {'A3824', 'B21137'},
#  {'A3832', 'B11232'},
#  {'A3867', 'B23233'},
#  {'A3899', 'B21266'},
#  {'A3910', 'B16079'},
#  {'A3914', 'B15100'},
#  {'A3918', 'B21653'},
#  {'A3945', 'B21494'},
#  {'A3961', 'B6857'},
#  {'A4037', 'B12492'},
#  {'A4057', 'B2936'},
#  {'A4063', 'B16279'},
#  {'A4086', 'B2505'},
#  {'A4129', 'B17835'},
#  {'A4133', 'B19340'},
#  {'A4136', 'B17583'},
#  {'A4241', 'B7644'},
#  {'A4258', 'B16837'},
#  {'A4287', 'B10286'},
#  {'A4328', 'B12706'},
#  {'A4370', 'B24325'},
#  {'A4379', 'B306'},
#  {'A4385', 'B8747'},
#  {'A4389', 'B13067'},
#  {'A4391', 'B10697'},
#  {'A4399', 'B17417'},
#  {'A4449', 'B17034'},
#  {'A4481', 'B12424'},
#  {'A4502', 'B1712'},
#  {'A4553', 'B10716'},
#  {'A4556', 'B18403'},
#  {'A4578', 'B20925'},
#  {'A4666', 'B19588'},
#  {'A4688', 'B1658'},
#  {'A4709', 'B7250'},
#  {'A4737', 'B1432'},
#  {'A4751', 'B1246'},
#  {'A4788', 'B20376'},
#  {'A4793', 'B5109'},
#  {'A4809', 'B23714'},
#  {'A4830', 'B3573'},
#  {'A4838', 'B1490'},
#  {'A4879', 'B10843'},
#  {'A4890', 'B15583'},
#  {'A4895', 'B10971'},
#  {'A4898', 'B19790'},
#  {'A4903', 'B6430'},
#  {'A4927', 'B21495'},
#  {'A4941', 'B22567'},
#  {'A4990', 'B1278'},
#  {'A4997', 'B4886'},
#  {'A5002', 'B2302'},
#  {'A5056', 'B18461'},
#  {'A5081', 'B15145'},
#  {'A5088', 'B2537'},
#  {'A5105', 'B5195'},
#  {'A5113', 'B8135'},
#  {'A5123', 'B6832'},
#  {'A5198', 'B3214'},
#  {'A5204', 'B4767'},
#  {'A5259', 'B10340'},
#  {'A5353', 'B20247'},
#  {'A5398', 'B22451'},
#  {'A5427', 'B15771'},
#  {'A5473', 'B18941'},
#  {'A5478', 'B19534'},
#  {'A5505', 'B3174'},
#  {'A5507', 'B8032'},
#  {'A5525', 'B15872'},
#  {'A5606', 'B20400'},
#  {'A5643', 'B22973'},
#  {'A5689', 'B13059'},
#  {'A5701', 'B7352'},
#  {'A5707', 'B14090'},
#  {'A5724', 'B22734'},
#  {'A5771', 'B13025'},
#  {'A5787', 'B8985'},
#  {'A5815', 'B1375'},
#  {'A5871', 'B9277'},
#  {'A5917', 'B21336'},
#  {'A5934', 'B11108'},
#  {'A6025', 'B23854'},
#  {'A6028', 'B8785'},
#  {'A6044', 'B20162'},
#  {'A6058', 'B17348'},
#  {'A6065', 'B8533'},
#  {'A6103', 'B18025'},
#  {'A6104', 'B187'},
#  {'A6111', 'B16827'},
#  {'A6127', 'B18855'},
#  {'A6149', 'B9177'},
#  {'A6153', 'B20490'},
#  {'A6169', 'B15909'},
#  {'A6199', 'B19366'},
#  {'A6225', 'B13833'},
#  {'A6271', 'B20127'},
#  {'A6274', 'B18296'},
#  {'A6289', 'B13556'},
#  {'A6294', 'B4022'},
#  {'A6315', 'B23465'},
#  {'A6331', 'B3073'},
#  {'A6371', 'B16858'},
#  {'A6376', 'B3090'},
#  {'A6403', 'B21843'},
#  {'A6425', 'B22688'},
#  {'A6441', 'B16674'},
#  {'A6470', 'B11453'},
#  {'A6489', 'B2835'},
#  {'A6504', 'B7361'},
#  {'A6545', 'B3109'},
#  {'A6569', 'B10862'},
#  {'A6571', 'B22070'},
#  {'A6591', 'B16701'},
#  {'A6594', 'B24251'},
#  {'A6612', 'B7178'},
#  {'A6616', 'B14235'},
#  {'A6626', 'B16387'},
#  {'A6632', 'B332'},
#  {'A6666', 'B22187'},
#  {'A6750', 'B19888'},
#  {'A6756', 'B8844'},
#  {'A6769', 'B19241'},
#  {'A6791', 'B6488'},
#  {'A6847', 'B11376'},
#  {'A6850', 'B12638'},
#  {'A6852', 'B21971'},
#  {'A6931', 'B14667'},
#  {'A6944', 'B23817'},
#  {'A6957', 'B15657'},
#  {'A6970', 'B24068'},
#  {'A6972', 'B2517'},
#  {'A7010', 'B19328'},
#  {'A7017', 'B11924'},
#  {'A7060', 'B6211'},
#  {'A7062', 'B1791'},
#  {'A7075', 'B4444'},
#  {'A7126', 'B20609'},
#  {'A7143', 'B8712'},
#  {'A7241', 'B4574'},
#  {'A7246', 'B20480'},
#  {'A7296', 'B13525'},
#  {'A7305', 'B7097'},
#  {'A7379', 'B5845'},
#  {'A7391', 'B4931'},
#  {'A7400', 'B16416'},
#  {'A7452', 'B8687'},
#  {'A7471', 'B11215'},
#  {'A7476', 'B5846'},
#  {'A7497', 'B9321'},
#  {'A7504', 'B13533'},
#  {'A7549', 'B11746'},
#  {'A7560', 'B6126'},
#  {'A7594', 'B17181'},
#  {'A7625', 'B20363'},
#  {'A7637', 'B15690'},
#  {'A7673', 'B24599'},
#  {'A7680', 'B17986'},
#  {'A7729', 'B7448'},
#  {'A7776', 'B23911'},
#  {'A7787', 'B20812'},
#  {'A7841', 'B10994'},
#  {'A7897', 'B13592'},
#  {'A7928', 'B18747'},
#  {'A7934', 'B23322'},
#  {'A7955', 'B19441'},
#  {'A7997', 'B337'},
#  {'A8001', 'B4172'},
#  {'A8022', 'B23395'},
#  {'A8036', 'B7418'},
#  {'A8067', 'B13871'},
#  {'A8088', 'B2187'},
#  {'A8141', 'B23548'},
#  {'A8143', 'B16147'},
#  {'A8162', 'B21573'},
#  {'A8166', 'B8892'},
#  {'A8214', 'B11814'},
#  {'A8241', 'B21735'},
#  {'A8268', 'B12092'},
#  {'A8275', 'B9855'},
#  {'A8280', 'B7225'},
#  {'A8317', 'B13364'},
#  {'A8401', 'B2752'},
#  {'A8428', 'B6967'},
#  {'A8485', 'B21387'},
#  {'A8505', 'B625'},
#  {'A8568', 'B20471'},
#  {'A8585', 'B6886'},
#  {'A8653', 'B18825'},
#  {'A8658', 'B17297'},
#  {'A8673', 'B3689'},
#  {'A8676', 'B23157'},
#  {'A8717', 'B9139'},
#  {'A8751', 'B8698'},
#  {'A8761', 'B2547'},
#  {'A8812', 'B22896'},
#  {'A8813', 'B22374'},
#  {'A8814', 'B15445'},
#  {'A8817', 'B8528'},
#  {'A8829', 'B16378'},
#  {'A8844', 'B3266'},
#  {'A8883', 'B12737'},
#  {'A8932', 'B22946'},
#  {'A8933', 'B7145'},
#  {'A8950', 'B8786'},
#  {'A8959', 'B12873'},
#  {'A9000', 'B18532'},
#  {'A9020', 'B14794'},
#  {'A9022', 'B22212'},
#  {'A9031', 'B20112'},
#  {'A9050', 'B13942'},
#  {'A9071', 'B22870'},
#  {'A9077', 'B3442'},
#  {'A9097', 'B13814'},
#  {'A9108', 'B22135'},
#  {'A9118', 'B2704'},
#  {'A9184', 'B9859'},
#  {'A9188', 'B377'},
#  {'A9228', 'B7180'},
#  {'A9231', 'B12113'},
#  {'A9284', 'B11027'},
#  {'A9314', 'B4536'},
#  {'A9381', 'B14547'},
#  {'A9386', 'B15260'},
#  {'A9433', 'B11321'},
#  {'A9624', 'B16353'},
#  {'A9765', 'B5067'},
#  {'A9771', 'B23377'},
#  {'A9821', 'B21359'},
#  {'A9837', 'B13074'},
#  {'A9872', 'B4358'},
#  {'A9875', 'B18547'},
#  {'A9901', 'B2210'},
#  {'A9930', 'B1989'},
#  {'A9937', 'B372'},
#  {'A9950', 'B21891'},
#  {'A9957', 'B9028'},
#  {'A9963', 'B5983'},
#  {'A9987', 'B23422'},
#  {'A10017', 'B1119'},
#  {'A10055', 'B10346'},
#  {'A10059', 'B23873'},
#  {'A10081', 'B21727'},
#  {'A10165', 'B17601'},
#  {'A10166', 'B8899'},
#  {'A10197', 'B6182'},
#  {'A10199', 'B3283'},
#  {'A10251', 'B2464'},
#  {'A10255', 'B10039'},
#  {'A10267', 'B240'},
#  {'A10356', 'B15781'},
#  {'A10380', 'B24568'},
#  {'A10387', 'B6562'},
#  {'A10442', 'B9719'},
#  {'A10455', 'B11885'},
#  {'A10496', 'B587'},
#  {'A10499', 'B23411'},
#  {'A10551', 'B12753'},
#  {'A10563', 'B3410'},
#  {'A10567', 'B12490'},
#  {'A10629', 'B12792'},
#  {'A10663', 'B4312'},
#  {'A10677', 'B5919'},
#  {'A10748', 'B12681'},
#  {'A10810', 'B19697'},
#  {'A10820', 'B20987'},
#  {'A10840', 'B7779'},
#  {'A10850', 'B1339'},
#  {'A10930', 'B9775'},
#  {'A11016', 'B6996'},
#  {'A11046', 'B3044'},
#  {'A11100', 'B7037'},
#  {'A11105', 'B4977'},
#  {'A11136', 'B22063'},
#  {'A11168', 'B14791'},
#  {'A11204', 'B20745'},
#  {'A11225', 'B23142'},
#  {'A11236', 'B23635'},
#  {'A11240', 'B9217'},
#  {'A11258', 'B3207'},
#  {'A11335', 'B18151'},
#  {'A11336', 'B13115'},
#  {'A11343', 'B24581'},
#  {'A11347', 'B1628'},
#  {'A11406', 'B10314'},
#  {'A11435', 'B16343'},
#  {'A11481', 'B19995'},
#  {'A11490', 'B10575'},
#  {'A11509', 'B11999'},
#  {'A11516', 'B23357'},
#  {'A11533', 'B23932'},
#  {'A11542', 'B22060'},
#  {'A11555', 'B7232'},
#  {'A11572', 'B6772'},
#  {'A11596', 'B19498'},
#  {'A11601', 'B18585'},
#  {'A11650', 'B13641'},
#  {'A11680', 'B13674'},
#  {'A11685', 'B5803'},
#  {'A11692', 'B5671'},
#  {'A11753', 'B19611'},
#  {'A11773', 'B8535'},
#  {'A11868', 'B18442'},
#  {'A11888', 'B2181'},
#  {'A11915', 'B23235'},
#  {'A11962', 'B13284'},
#  {'A11965', 'B9651'},
#  {'A11974', 'B11709'},
#  {'A12026', 'B15864'},
#  {'A12033', 'B23662'},
#  {'A12050', 'B6942'},
#  {'A12114', 'B11897'},
#  {'A12121', 'B4640'},
#  {'A12146', 'B21281'},
#  {'A12200', 'B4215'},
#  {'A12214', 'B18255'},
#  {'A12220', 'B12389'},
#  {'A12229', 'B5257'},
#  {'A12252', 'B7381'},
#  {'A12256', 'B10768'},
#  {'A12276', 'B3284'},
#  {'A12353', 'B23587'},
#  {'A12435', 'B9388'},
#  {'A12436', 'B13603'},
#  {'A12472', 'B21988'},
#  {'A12483', 'B15933'},
#  {'A12490', 'B13540'},
#  {'A12493', 'B17224'},
#  {'A12521', 'B16339'},
#  {'A12528', 'B8854'},
#  {'A12561', 'B11753'},
#  {'A12585', 'B13557'},
#  {'A12594', 'B5849'},
#  {'A12618', 'B24444'},
#  {'A12655', 'B15620'},
#  {'A12657', 'B23573'},
#  {'A12668', 'B192'},
#  {'A12731', 'B12686'},
#  {'A12734', 'B10008'},
#  {'A12748', 'B8419'},
#  {'A12750', 'B280'},
#  {'A12831', 'B23121'},
#  {'A12849', 'B11733'},
#  {'A12882', 'B5616'},
#  {'A12895', 'B320'},
#  {'A12933', 'B16749'},
#  {'A12937', 'B12818'},
#  {'A12958', 'B19249'},
#  {'A13018', 'B16636'},
#  {'A13022', 'B23814'},
#  {'A13055', 'B20187'},
#  {'A13173', 'B1576'},
#  {'A13176', 'B12176'},
#  {'A13181', 'B12417'},
#  {'A13191', 'B1066'},
#  {'A13193', 'B16150'},
#  {'A13206', 'B4914'},
#  {'A13235', 'B4983'},
#  {'A13257', 'B22325'},
#  {'A13267', 'B18101'},
#  {'A13279', 'B2800'},
#  {'A13295', 'B21754'},
#  {'A13302', 'B4455'},
#  {'A13319', 'B24037'},
#  {'A13322', 'B20489'},
#  {'A13364', 'B20912'},
#  {'A13392', 'B20952'},
#  {'A13407', 'B14926'},
#  {'A13436', 'B1898'},
#  {'A13579', 'B4749'},
#  {'A13594', 'B18598'},
#  {'A13633', 'B2826'},
#  {'A13661', 'B8457'},
#  {'A13795', 'B718'},
#  {'A13800', 'B12073'},
#  {'A13835', 'B1486'},
#  {'A13956', 'B9973'},
#  {'A13959', 'B10003'},
#  {'A13969', 'B20728'},
#  {'A13995', 'B8074'},
#  {'A14006', 'B16725'},
#  {'A14020', 'B11678'},
#  {'A14025', 'B14341'},
#  {'A14063', 'B22366'},
#  {'A14103', 'B14431'},
#  {'A14107', 'B21974'},
#  {'A14122', 'B6559'},
#  {'A14160', 'B1617'},
#  {'A14168', 'B5730'},
#  {'A14230', 'B13584'},
#  {'A14238', 'B232'},
#  {'A14249', 'B10406'},
#  {'A14270', 'B10674'},
#  {'A14275', 'B16538'},
#  {'A14280', 'B8603'},
#  {'A14331', 'B5893'},
#  {'A14349', 'B12749'},
#  {'A14362', 'B22019'},
#  {'A14373', 'B16157'},
#  {'A14379', 'B22230'},
#  {'A14412', 'B11883'},
#  {'A14428', 'B23865'},
#  {'A14449', 'B7540'},
#  {'A14474', 'B20482'},
#  {'A14501', 'B23232'},
#  {'A14503', 'B21172'},
#  {'A14508', 'B14417'},
#  {'A14529', 'B20517'},
#  {'A14550', 'B23460'},
#  {'A14573', 'B8302'},
#  {'A14609', 'B1377'},
#  {'A14675', 'B22632'},
#  {'A14700', 'B2341'},
#  {'A14719', 'B19064'},
#  {'A14725', 'B7998'},
#  {'A14729', 'B10652'},
#  {'A14764', 'B8217'},
#  {'A14809', 'B5574'},
#  {'A14829', 'B22502'},
#  {'A14871', 'B16239'},
#  {'A14899', 'B10345'},
#  {'A14909', 'B18812'},
#  {'A14914', 'B11766'},
#  {'A14915', 'B4202'},
#  {'A14946', 'B20698'},
#  {'A14958', 'B21316'},
#  {'A14988', 'B4903'},
#  {'A15012', 'B8378'},
#  {'A15015', 'B12623'},
#  {'A15039', 'B14737'},
#  {'A15063', 'B15689'},
#  {'A15072', 'B22145'},
#  {'A15074', 'B18865'},
#  {'A15076', 'B16642'},
#  {'A15105', 'B22535'},
#  {'A15111', 'B4482'},
#  {'A15156', 'B4025'},
#  {'A15159', 'B24117'},
#  {'A15169', 'B13235'},
#  {'A15180', 'B6057'},
#  {'A15184', 'B10660'},
#  {'A15189', 'B6278'},
#  {'A15222', 'B6518'},
#  {'A15284', 'B23331'},
#  {'A15309', 'B11455'},
#  {'A15365', 'B14660'},
#  {'A15495', 'B18122'},
#  {'A15536', 'B4609'},
#  {'A15554', 'B8523'},
#  {'A15570', 'B14536'},
#  {'A15620', 'B5641'},
#  {'A15636', 'B19223'},
#  {'A15641', 'B7014'},
#  {'A15646', 'B23310'},
#  {'A15651', 'B16583'},
#  {'A15678', 'B13492'},
#  {'A15698', 'B20893'},
#  {'A15766', 'B9357'},
#  {'A15830', 'B7683'},
#  {'A15851', 'B23319'},
#  {'A15859', 'B15879'},
#  {'A15907', 'B10747'},
#  {'A15941', 'B4059'},
#  {'A15966', 'B2062'},
#  {'A15983', 'B23213'},
#  {'A16000', 'B7907'},
#  {'A16028', 'B17119'},
#  {'A16091', 'B7374'},
#  {'A16183', 'B10497'},
#  {'A16287', 'B12296'},
#  {'A16304', 'B22545'},
#  {'A16336', 'B7111'},
#  {'A16352', 'B22975'},
#  {'A16358', 'B321'},
#  {'A16373', 'B24602'},
#  {'A16413', 'B18275'},
#  {'A16423', 'B6569'},
#  {'A16466', 'B13552'},
#  {'A16475', 'B24415'},
#  {'A16486', 'B5952'},
#  {'A16487', 'B6466'},
#  {'A16502', 'B11793'},
#  {'A16545', 'B22280'},
#  {'A16587', 'B19652'},
#  {'A16748', 'B14306'},
#  {'A16803', 'B18327'},
#  {'A16809', 'B16590'},
#  {'A16904', 'B229'},
#  {'A16930', 'B11280'},
#  {'A16962', 'B1548'},
#  {'A16964', 'B2179'},
#  {'A16990', 'B822'},
#  {'A17008', 'B16306'},
#  {'A17028', 'B20899'},
#  {'A17031', 'B9928'},
#  {'A17034', 'B22444'},
#  {'A17039', 'B11326'},
#  {'A17056', 'B3854'},
#  {'A17084', 'B22449'},
#  {'A17094', 'B24237'},
#  {'A17163', 'B15981'},
#  {'A17174', 'B4094'},
#  {'A17191', 'B1331'},
#  {'A17194', 'B9665'},
#  {'A17212', 'B24334'},
#  {'A17216', 'B19058'},
#  {'A17259', 'B3358'},
#  {'A17286', 'B19518'},
#  {'A17315', 'B16759'},
#  {'A17330', 'B5604'},
#  {'A17338', 'B483'},
#  {'A17355', 'B15943'},
#  {'A17454', 'B20657'},
#  {'A17455', 'B4612'},
#  {'A17482', 'B17897'},
#  {'A17505', 'B24588'},
#  {'A17512', 'B22713'},
#  {'A17581', 'B12611'},
#  {'A17593', 'B178'},
#  {'A17626', 'B15597'},
#  {'A17629', 'B10751'},
#  {'A17630', 'B13521'},
#  {'A17741', 'B2977'},
#  {'A17750', 'B19718'},
#  {'A17791', 'B22294'},
#  {'A17794', 'B7375'},
#  {'A17825', 'B13878'},
#  {'A17834', 'B19489'},
#  {'A17845', 'B380'},
#  {'A17869', 'B16808'},
#  {'A17887', 'B5286'},
#  {'A17921', 'B12964'},
#  {'A17952', 'B3973'},
#  {'A18003', 'B12903'},
#  {'A18005', 'B17365'},
#  {'A18084', 'B23979'},
#  {'A18137', 'B14589'},
#  {'A18138', 'B13072'},
#  {'A18141', 'B17452'},
#  {'A18164', 'B22167'},
#  {'A18200', 'B5316'},
#  {'A18207', 'B18438'},
#  {'A18216', 'B5285'},
#  {'A18235', 'B20391'},
#  {'A18268', 'B21567'},
#  {'A18291', 'B13945'},
#  {'A18336', 'B416'},
#  {'A18399', 'B21411'},
#  {'A18576', 'B22279'},
#  {'A18616', 'B16566'},
#  {'A18637', 'B2617'},
#  {'A18670', 'B21656'},
#  {'A18707', 'B3431'},
#  {'A18727', 'B7541'},
#  {'A18732', 'B19477'},
#  {'A18748', 'B17673'},
#  {'A18770', 'B12052'},
#  {'A18783', 'B10561'},
#  {'A18795', 'B5416'},
#  {'A18830', 'B11388'},
#  {'A18839', 'B9115'},
#  {'A18852', 'B23160'},
#  {'A18859', 'B5289'},
#  {'A18892', 'B11197'},
#  {'A18921', 'B8572'},
#  {'A18945', 'B10038'},
#  {'A18946', 'B10786'},
#  {'A18994', 'B8655'},
#  {'A19028', 'B15397'},
#  {'A19061', 'B1166'},
#  {'A19074', 'B14544'},
#  {'A19082', 'B24595'},
#  {'A19103', 'B6008'},
#  {'A19112', 'B8426'},
#  {'A19133', 'B13247'},
#  {'A19191', 'B22658'},
#  {'A19235', 'B24503'},
#  {'A19240', 'B11122'},
#  {'A19242', 'B11448'},
#  {'A19253', 'B23249'},
#  {'A19279', 'B23775'},
#  {'A19292', 'B12746'},
#  {'A19308', 'B21857'},
#  {'A19348', 'B8126'},
#  {'A19350', 'B6918'},
#  {'A19375', 'B7927'},
#  {'A19387', 'B2776'},
#  {'A19388', 'B8543'},
#  {'A19398', 'B19073'},
#  {'A19447', 'B18559'},
#  {'A19450', 'B4126'},
#  {'A19481', 'B7301'},
#  {'A19487', 'B422'},
#  {'A19489', 'B5492'},
#  {'A19511', 'B16093'},
#  {'A19537', 'B12512'},
#  {'A19550', 'B2928'},
#  {'A19572', 'B10700'},
#  {'A19587', 'B5188'},
#  {'A19717', 'B7872'},
#  {'A19725', 'B24206'},
#  {'A19737', 'B23783'},
#  {'A19743', 'B745'},
#  {'A19766', 'B21157'},
#  {'A19824', 'B17160'},
#  {'A19928', 'B1196'},
#  {'A19960', 'B10793'},
#  {'A19970', 'B6687'},
#  {'A19993', 'B14960'},
#  {'A20015', 'B12215'},
#  {'A20019', 'B24427'},
#  {'A20036', 'B4994'},
#  {'A20078', 'B5827'},
#  {'A20085', 'B22110'},
#  {'A20100', 'B22434'},
#  {'A20110', 'B22284'},
#  {'A20160', 'B20220'},
#  {'A20212', 'B18761'},
#  {'A20235', 'B12511'},
#  {'A20251', 'B6560'},
#  {'A20258', 'B949'},
#  {'A20260', 'B311'},
#  {'A20319', 'B2652'},
#  {'A20337', 'B15627'},
#  {'A20346', 'B6061'},
#  {'A20361', 'B6198'},
#  {'A20365', 'B65'},
#  {'A20368', 'B21163'},
#  {'A20370', 'B18460'},
#  {'A20371', 'B18287'},
#  {'A20372', 'B6421'},
#  {'A20375', 'B7297'},
#  {'A20403', 'B23152'},
#  {'A20412', 'B24537'},
#  {'A20426', 'B14861'},
#  {'A20453', 'B19513'},
#  {'A20509', 'B3571'},
#  {'A20522', 'B11457'},
#  {'A20543', 'B23004'},
#  {'A20554', 'B10523'},
#  {'A20562', 'B10001'},
#  {'A20567', 'B19065'},
#  {'A20600', 'B4757'},
#  {'A20606', 'B4858'},
#  {'A20621', 'B12218'},
#  {'A20638', 'B3201'},
#  {'A20676', 'B18048'},
#  {'A20741', 'B18128'},
#  {'A20795', 'B22626'},
#  {'A20818', 'B17911'},
#  {'A20832', 'B6005'},
#  {'A20835', 'B14587'},
#  {'A20840', 'B10185'},
#  {'A20846', 'B8716'},
#  {'A20870', 'B146'},
#  {'A20890', 'B12168'},
#  {'A20941', 'B18491'},
#  {'A20990', 'B9955'},
#  {'A21040', 'B7529'},
#  {'A21059', 'B21159'},
#  {'A21075', 'B20895'},
#  {'A21090', 'B1087'},
#  {'A21094', 'B8292'},
#  {'A21120', 'B13047'},
#  {'A21129', 'B11157'},
#  {'A21131', 'B1323'},
#  {'A21159', 'B983'},
#  {'A21163', 'B1863'},
#  {'A21200', 'B4715'},
#  {'A21203', 'B6688'},
#  {'A21208', 'B23860'},
#  {'A21222', 'B21434'},
#  {'A21256', 'B17661'},
#  {'A21259', 'B12350'},
#  {'A21273', 'B13398'},
#  {'A21349', 'B1788'},
#  {'A21396', 'B10141'},
#  {'A21450', 'B7041'},
#  {'A21452', 'B24296'},
#  {'A21534', 'B12479'},
#  {'A21536', 'B11879'},
#  {'A21543', 'B14433'},
#  {'A21566', 'B1445'},
#  {'A21579', 'B1763'},
#  {'A21622', 'B9485'},
#  {'A21651', 'B18099'},
#  {'A21656', 'B5235'},
#  {'A21675', 'B23326'},
#  {'A21679', 'B8268'},
#  {'A21688', 'B9273'},
#  {'A21690', 'B20931'},
#  {'A21708', 'B7613'},
#  {'A21778', 'B20606'},
#  {'A21812', 'B12406'},
#  {'A21818', 'B5777'},
#  {'A21823', 'B21544'},
#  {'A21841', 'B20168'},
#  {'A21855', 'B15005'},
#  {'A21950', 'B6041'},
#  {'A21960', 'B4454'},
#  {'A21962', 'B3989'},
#  {'A21972', 'B17152'},
#  {'A21996', 'B3074'},
#  {'A22049', 'B9463'},
#  {'A22071', 'B6525'},
#  {'A22074', 'B2566'},
#  {'A22109', 'B4556'},
#  {'A22119', 'B20555'},
#  {'A22157', 'B11150'},
#  {'A22208', 'B22068'},
#  {'A22212', 'B9798'},
#  {'A22263', 'B12970'},
#  {'A22269', 'B18802'},
#  {'A22313', 'B20934'},
#  {'A22331', 'B7761'},
#  {'A22348', 'B17991'},
#  {'A22365', 'B21033'},
#  {'A22375', 'B709'},
#  {'A22402', 'B19124'},
#  {'A22424', 'B2167'},
#  {'A22448', 'B23552'},
#  {'A22543', 'B17701'},
#  {'A22588', 'B13302'},
#  {'A22617', 'B19155'},
#  {'A22641', 'B9356'},
#  {'A22698', 'B10295'},
#  {'A22711', 'B20620'},
#  {'A22765', 'B8852'},
#  {'A22868', 'B5718'},
#  {'A22913', 'B9234'},
#  {'A22917', 'B14577'},
#  {'A22931', 'B20212'},
#  {'A22943', 'B23155'},
#  {'A22951', 'B3569'},
#  {'A22953', 'B11434'},
#  {'A23008', 'B15680'},
#  {'A23038', 'B518'},
#  {'A23054', 'B24315'},
#  {'A23079', 'B23670'},
#  {'A23096', 'B17589'},
#  {'A23107', 'B12065'},
#  {'A23118', 'B4943'},
#  {'A23133', 'B12060'},
#  {'A23134', 'B12523'},
#  {'A23160', 'B13145'},
#  {'A23203', 'B1803'},
#  {'A23259', 'B13272'},
#  {'A23267', 'B19144'},
#  {'A23273', 'B7977'},
#  {'A23297', 'B614'},
#  {'A23353', 'B11529'},
#  {'A23384', 'B20598'},
#  {'A23387', 'B17539'},
#  {'A23389', 'B8545'},
#  {'A23474', 'B17032'},
#  {'A23534', 'B6018'},
#  {'A23617', 'B2853'},
#  {'A23626', 'B14270'},
#  {'A23641', 'B1907'},
#  {'A23659', 'B81'},
#  {'A23669', 'B12891'},
#  {'A23756', 'B8803'},
#  {'A23776', 'B18049'},
#  {'A23839', 'B735'},
#  {'A23860', 'B9888'},
#  {'A23885', 'B8540'},
#  {'A23896', 'B22200'},
#  {'A23899', 'B14789'},
#  {'A23905', 'B21767'},
#  {'A23912', 'B20208'},
#  {'A23926', 'B23984'},
#  {'A23953', 'B2735'},
#  {'A24025', 'B9349'},
#  {'A24044', 'B2053'},
#  {'A24057', 'B10252'},
#  {'A24060', 'B18609'},
#  {'A24065', 'B17346'},
#  {'A24103', 'B19276'},
#  {'A24147', 'B6052'},
#  {'A24157', 'B14292'},
#  {'A24163', 'B2577'},
#  {'A24166', 'B14850'},
#  {'A24171', 'B7243'},
#  {'A24208', 'B784'},
#  {'A24222', 'B22344'},
#  {'A24284', 'B19206'},
#  {'A24320', 'B23956'},
#  {'A24415', 'B159'},
#  {'A24476', 'B2717'},
#  {'A24485', 'B4275'},
#  {'A24565', 'B17944'},
#  {'A24623', 'B3805'},
#  {'A24647', 'B2386'},
#  {'A24685', 'B1467'},
#  {'A24737', 'B17409'},
#  {'A24742', 'B13268'},
#  {'A24774', 'B6704'},
#  {'A24783', 'B16455'},
#  {'A24845', 'B1288'},
#  {'A24859', 'B19648'},
#  {'A24875', 'B22175'},
#  {'A24880', 'B1059'},
#  {'A24915', 'B11401'},
#  {'A24918', 'B10785'},
#  {'A24938', 'B23001'},
#  {'A24951', 'B17217'},
#  {'A25028', 'B10892'},
#  {'A25068', 'B17798'},
#  {'A25085', 'B12209'},
#  {'A25094', 'B3493'},
#  {'A25118', 'B1817'},
#  {'A25122', 'B14893'},
#  {'A25137', 'B22889'},
#  {'A25151', 'B7841'},
#  {'A25168', 'B22245'},
#  {'A25183', 'B2161'},
#  {'A25217', 'B10524'},
#  {'A25237', 'B11084'},
#  {'A25243', 'B6359'},
#  {'A25252', 'B13639'},
#  {'A25277', 'B16237'},
#  {'A25283', 'B10250'},
#  {'A25308', 'B15945'},
#  {'A25318', 'B6675'},
#  {'A25322', 'B14776'}]

# %%
#tworzymy graf zgodnie z dopasowaniami
G2 = nx.Graph()

# Dodaj węzły z obu zbiorów danych
for i in range(len(census)):
    G2.add_node(f'A{i}', record=census.iloc[i])

for j in range(len(cis)):
    G2.add_node(f'B{j}', record=cis.iloc[j])

# Dodaj krawędzie na podstawie najbliższych sąsiadów
for _, row in tp.iterrows():
    G2.add_edges_from([(row["index_census"], row["index_cis"])])

# %%
#tworzymy graf zgodnie z dopasowaniami
clusterstp = list(nx.connected_components(G2))
clusterstp = [component for component in nx.connected_components(G2) if len(component) > 1]

## Wyświetlenie informacji o klastrach
#print(f"Liczba klastrów: {len(clusterstp)}")
#for i, cluster in enumerate(clusterstp):
#    print(f"Klaster {i+1}: {cluster}")

# %%
#definiujemy funkcję zamieniającą wartości klastrów na identyfikatory
def clusters_to_labels(clusters, node_list, start_label=1):
    labels = [0] * len(node_list)
    for cluster_id, cluster in enumerate(clusters, start=start_label):
        for node in cluster:
            labels[node_list.index(node)] = cluster_id
    return labels

# %%
#sortujemy
all_nodes = sorted({node for cluster in clusterstp + clusterspp for node in cluster})

# %%
#tworzymy zbiory dla miar jakości
labels_true = clusters_to_labels(clusterstp, all_nodes)
labels_pred = clusters_to_labels(clusterspp, all_nodes)

# %%
labels_true
# Out:
# [386,
#  387,
#  388,
#  389,
#  390,
#  391,
#  392,
#  393,
#  394,
#  395,
#  41,
#  396,
#  42,
#  397,
#  398,
#  399,
#  400,
#  401,
#  402,
#  403,
#  404,
#  43,
#  405,
#  406,
#  407,
#  408,
#  409,
#  410,
#  44,
#  45,
#  411,
#  412,
#  413,
#  414,
#  46,
#  415,
#  416,
#  417,
#  418,
#  419,
#  420,
#  421,
#  422,
#  423,
#  424,
#  425,
#  426,
#  47,
#  427,
#  428,
#  429,
#  430,
#  48,
#  431,
#  432,
#  433,
#  434,
#  435,
#  436,
#  437,
#  438,
#  439,
#  440,
#  441,
#  442,
#  443,
#  444,
#  445,
#  446,
#  447,
#  448,
#  449,
#  450,
#  451,
#  452,
#  453,
#  454,
#  49,
#  455,
#  456,
#  457,
#  458,
#  459,
#  460,
#  461,
#  462,
#  463,
#  464,
#  465,
#  466,
#  467,
#  468,
#  469,
#  470,
#  471,
#  472,
#  473,
#  474,
#  6,
#  475,
#  476,
#  477,
#  478,
#  479,
#  50,
#  480,
#  481,
#  482,
#  483,
#  484,
#  485,
#  486,
#  487,
#  488,
#  489,
#  490,
#  491,
#  492,
#  493,
#  494,
#  495,
#  496,
#  497,
#  498,
#  499,
#  500,
#  501,
#  502,
#  503,
#  504,
#  505,
#  506,
#  507,
#  508,
#  7,
#  509,
#  510,
#  511,
#  512,
#  513,
#  51,
#  514,
#  515,
#  516,
#  517,
#  518,
#  519,
#  520,
#  52,
#  521,
#  522,
#  523,
#  524,
#  525,
#  526,
#  53,
#  527,
#  528,
#  529,
#  530,
#  531,
#  532,
#  533,
#  54,
#  534,
#  535,
#  536,
#  537,
#  538,
#  539,
#  540,
#  541,
#  542,
#  543,
#  544,
#  545,
#  546,
#  547,
#  548,
#  549,
#  55,
#  550,
#  551,
#  552,
#  553,
#  554,
#  555,
#  556,
#  557,
#  558,
#  559,
#  560,
#  561,
#  562,
#  563,
#  564,
#  565,
#  566,
#  567,
#  568,
#  569,
#  570,
#  571,
#  572,
#  573,
#  574,
#  575,
#  576,
#  577,
#  578,
#  579,
#  580,
#  581,
#  582,
#  56,
#  583,
#  584,
#  585,
#  586,
#  587,
#  588,
#  589,
#  590,
#  591,
#  592,
#  57,
#  593,
#  594,
#  58,
#  595,
#  596,
#  597,
#  598,
#  599,
#  600,
#  601,
#  602,
#  603,
#  604,
#  59,
#  605,
#  606,
#  607,
#  608,
#  609,
#  610,
#  60,
#  611,
#  612,
#  61,
#  613,
#  614,
#  615,
#  62,
#  616,
#  63,
#  617,
#  618,
#  619,
#  620,
#  621,
#  622,
#  623,
#  624,
#  625,
#  626,
#  627,
#  64,
#  628,
#  629,
#  630,
#  65,
#  631,
#  632,
#  633,
#  634,
#  635,
#  636,
#  637,
#  638,
#  639,
#  640,
#  641,
#  642,
#  643,
#  644,
#  645,
#  646,
#  647,
#  648,
#  649,
#  650,
#  66,
#  651,
#  652,
#  653,
#  654,
#  655,
#  656,
#  657,
#  658,
#  67,
#  68,
#  69,
#  659,
#  660,
#  661,
#  662,
#  663,
#  664,
#  665,
#  666,
#  667,
#  668,
#  669,
#  670,
#  671,
#  672,
#  673,
#  674,
#  675,
#  676,
#  70,
#  677,
#  678,
#  679,
#  680,
#  681,
#  682,
#  71,
#  683,
#  684,
#  685,
#  686,
#  687,
#  688,
#  689,
#  690,
#  691,
#  692,
#  693,
#  694,
#  72,
#  8,
#  695,
#  696,
#  73,
#  697,
#  698,
#  699,
#  700,
#  701,
#  702,
#  703,
#  704,
#  705,
#  706,
#  707,
#  708,
#  709,
#  710,
#  711,
#  712,
#  713,
#  714,
#  1,
#  715,
#  74,
#  716,
#  717,
#  718,
#  75,
#  719,
#  720,
#  721,
#  722,
#  723,
#  724,
#  725,
#  726,
#  727,
#  728,
#  729,
#  730,
#  731,
#  732,
#  733,
#  734,
#  735,
#  736,
#  737,
#  738,
#  739,
#  740,
#  741,
#  742,
#  743,
#  744,
#  745,
#  76,
#  77,
#  746,
#  747,
#  748,
#  749,
#  750,
#  78,
#  79,
#  751,
#  752,
#  753,
#  754,
#  755,
#  756,
#  757,
#  758,
#  759,
#  760,
#  761,
#  762,
#  763,
#  80,
#  764,
#  765,
#  766,
#  767,
#  768,
#  9,
#  81,
#  769,
#  770,
#  771,
#  772,
#  773,
#  774,
#  775,
#  776,
#  777,
#  778,
#  779,
#  780,
#  781,
#  782,
#  783,
#  784,
#  785,
#  786,
#  787,
#  788,
#  789,
#  790,
#  82,
#  791,
#  792,
#  793,
#  10,
#  83,
#  794,
#  795,
#  796,
#  797,
#  798,
#  799,
#  800,
#  801,
#  802,
#  803,
#  804,
#  805,
#  806,
#  807,
#  808,
#  809,
#  810,
#  811,
#  812,
#  813,
#  814,
#  815,
#  816,
#  817,
#  818,
#  819,
#  820,
#  821,
#  822,
#  823,
#  824,
#  825,
#  826,
#  827,
#  828,
#  829,
#  830,
#  831,
#  832,
#  833,
#  834,
#  835,
#  836,
#  837,
#  838,
#  84,
#  839,
#  840,
#  841,
#  842,
#  843,
#  844,
#  845,
#  846,
#  847,
#  848,
#  849,
#  850,
#  85,
#  851,
#  852,
#  853,
#  854,
#  855,
#  856,
#  857,
#  858,
#  859,
#  860,
#  861,
#  862,
#  863,
#  864,
#  865,
#  866,
#  867,
#  868,
#  869,
#  870,
#  871,
#  872,
#  873,
#  874,
#  875,
#  86,
#  876,
#  877,
#  878,
#  879,
#  880,
#  881,
#  87,
#  882,
#  883,
#  884,
#  885,
#  886,
#  887,
#  888,
#  889,
#  890,
#  891,
#  11,
#  892,
#  893,
#  894,
#  895,
#  896,
#  897,
#  898,
#  899,
#  900,
#  88,
#  901,
#  902,
#  89,
#  903,
#  904,
#  905,
#  906,
#  907,
#  908,
#  909,
#  910,
#  911,
#  912,
#  913,
#  914,
#  915,
#  916,
#  917,
#  918,
#  919,
#  920,
#  921,
#  922,
#  923,
#  90,
#  924,
#  925,
#  926,
#  927,
#  928,
#  929,
#  930,
#  931,
#  932,
#  933,
#  91,
#  934,
#  935,
#  936,
#  937,
#  938,
#  92,
#  939,
#  940,
#  941,
#  942,
#  943,
#  944,
#  93,
#  945,
#  946,
#  947,
#  948,
#  949,
#  950,
#  951,
#  952,
#  94,
#  953,
#  954,
#  955,
#  956,
#  957,
#  958,
#  959,
#  960,
#  961,
#  962,
#  12,
#  963,
#  964,
#  965,
#  966,
#  967,
#  968,
#  969,
#  970,
#  971,
#  95,
#  96,
#  97,
#  98,
#  99,
#  100,
#  101,
#  102,
#  103,
#  104,
#  105,
#  106,
#  107,
#  108,
#  109,
#  13,
#  110,
#  111,
#  112,
#  113,
#  114,
#  115,
#  116,
#  117,
#  118,
#  119,
#  120,
#  121,
#  122,
#  123,
#  124,
#  125,
#  126,
#  127,
#  128,
#  14,
#  2,
#  129,
#  130,
#  131,
#  132,
#  133,
#  134,
#  135,
#  136,
#  137,
#  15,
#  138,
#  139,
#  140,
#  141,
#  142,
#  16,
#  17,
#  143,
#  144,
#  145,
#  146,
#  147,
#  148,
#  149,
#  150,
#  151,
#  18,
#  152,
#  153,
#  154,
#  155,
#  156,
#  19,
#  157,
#  158,
#  159,
#  160,
#  161,
#  162,
#  163,
#  164,
#  165,
#  166,
#  3,
#  167,
#  168,
#  169,
#  20,
#  170,
#  171,
#  172,
#  173,
#  174,
#  175,
#  176,
#  21,
#  177,
#  178,
#  179,
#  180,
#  181,
#  182,
#  183,
#  184,
#  185,
#  186,
#  187,
#  188,
#  189,
#  190,
#  191,
#  192,
#  193,
#  194,
#  195,
#  196,
#  197,
#  198,
#  199,
#  200,
#  201,
#  202,
#  203,
#  204,
#  205,
#  22,
#  23,
#  206,
#  207,
#  208,
#  209,
#  210,
#  211,
#  212,
#  213,
#  24,
#  214,
#  215,
#  216,
#  25,
#  26,
#  217,
#  218,
#  219,
#  220,
#  221,
#  222,
#  223,
#  224,
#  225,
#  226,
#  227,
#  228,
#  27,
#  229,
#  230,
#  231,
#  232,
#  233,
#  234,
#  235,
#  236,
#  237,
#  238,
#  239,
#  240,
#  241,
#  242,
#  243,
#  244,
#  245,
#  246,
#  247,
#  248,
#  249,
#  250,
#  251,
#  252,
#  253,
#  254,
#  255,
#  256,
#  257,
#  258,
#  259,
#  260,
#  261,
#  262,
#  263,
#  264,
#  265,
#  266,
#  267,
#  268,
#  269,
#  270,
#  271,
#  272,
#  273,
#  274,
#  275,
#  276,
#  277,
#  278,
#  279,
#  280,
#  28,
#  281,
#  282,
#  283,
#  284,
#  29,
#  285,
#  286,
#  287,
#  288,
#  289,
#  290,
#  291,
#  292,
#  293,
#  294,
#  295,
#  296,
#  297,
#  298,
#  299,
#  30,
#  300,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  31,
#  309,
#  310,
#  311,
#  32,
#  312,
#  313,
#  4,
#  314,
#  315,
#  316,
#  317,
#  318,
#  33,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  34,
#  334,
#  335,
#  336,
#  35,
#  337,
#  338,
#  36,
#  339,
#  340,
#  341,
#  37,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  352,
#  353,
#  354,
#  355,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  362,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  370,
#  371,
#  38,
#  372,
#  5,
#  373,
#  374,
#  39,
#  375,
#  376,
#  377,
#  378,
#  379,
#  380,
#  381,
#  40,
#  382,
#  383,
#  384,
#  385,
#  787,
#  524,
#  485,
#  712,
#  395,
#  90,
#  823,
#  799,
#  61,
#  135,
#  968,
#  921,
#  67,
#  166,
#  872,
#  431,
#  208,
#  567,
#  387,
#  538,
#  615,
#  786,
#  963,
#  704,
#  434,
#  948,
#  562,
#  501,
#  587,
#  ...]

# %%
#przykład działania funkcji clusters_to_labels na prostszych danych

data = [{1, 3}, {5, 4}, {2, 6}]
data2 = [{1, 3}, {2, 4}, {7, 5}]

all_data = sorted({node for cluster in data + data2 for node in cluster})
print(clusters_to_labels(data, all_data))
print(clusters_to_labels(data2, all_data))
# Out:
# [1, 3, 1, 2, 2, 3, 0]
# [1, 2, 1, 2, 3, 0, 3]

# %%
#obliczamy różne miary jakości

sklearn.metrics.f1_score(labels_true, labels_pred, average='weighted')
# Out:
# 0.9938398357289527

# %%
sklearn.metrics.precision_score(labels_true, labels_pred, average='weighted')
# Out:
# 0.9938398357289527

# %%
sklearn.metrics.recall_score(labels_true, labels_pred, average='weighted')
# Out:
# 0.9938398357289527

# %%
sklearn.metrics.homogeneity_score(labels_true, labels_pred)
# Out:
# 0.9985768206297091

# %%
sklearn.metrics.completeness_score(labels_true, labels_pred)
# Out:
# 0.9985768206297091

# %%
sklearn.metrics.v_measure_score(labels_true, labels_pred)
# Out:
# 0.9985768206297091

# %%
sklearn.metrics.adjusted_rand_score(labels_true, labels_pred)
# Out:
# 0.9786907460555216

# %%
sklearn.metrics.mutual_info_score(labels_true, labels_pred)
# Out:
# 6.868238820729755

# %%
sklearn.metrics.normalized_mutual_info_score(labels_true, labels_pred)
# Out:
# 0.9985768206297091

# %%
#przygotowanie zbiorów dopasowań unikalnych dla clusterspp i clusterstp
set_pred = (set(tuple(sorted(pair)) for pair in clusterspp))
set_true = (set(tuple(sorted(pair)) for pair in clusterstp))

print(set_pred - set_true) #pary dopasowane wg modelu, a nie w rzeczywistości
print(set_true - set_pred) #pary dopasowane w rzeczywistości, jednak nie wg modelu
# Out:
# {('A23474', 'B17032'), ('A15495', 'B18122'), ('A22711', 'B20620'), ('A7934', 'B23322'), ('A11100', 'B7037'), ('A8067', 'B13871')}
# {('A7934', 'B21171'), ('A22711', 'B13752'), ('A15495', 'B18117'), ('A11100', 'B2727'), ('A8067', 'B4209'), ('A23474', 'B1603')}

# %%
set_pred - set_true
# Out:
# {('A11100', 'B7037'),
#  ('A15495', 'B18122'),
#  ('A22711', 'B20620'),
#  ('A23474', 'B17032'),
#  ('A7934', 'B23322'),
#  ('A8067', 'B13871')}

# %% [raw]
# set_true - set_pred

# %%
census.iloc[['11100', '15495', '22711', '23474', '7934', '8067']]
# Out:
#        index      person_id pername1  pername2  sex  dob_day  dob_mon  \
# 11100  11100   M660XT013001    EMILY      WEBB    F     26.0        5
# 15495  15495  PO272DD003001    AMBEV      HING  NaN     23.0        1
# 22711  22711  SW207UU064002      MIA    MORRIS    F     26.0        6
# 23474  23474  SW433XS013002     JOSH   STEWART    M     16.0        9
# 7934    7934  LS451GL017003    MOLLY  MABSHALL    F     20.0        3
# 8067    8067  LS451GR084002    HARRY    GIBSON    M     18.0       10
#
#        dob_year              enumcap   enumpc  \
# 11100    1935.0  13 SPRINGFIELD ROAD   M660XT
# 15495    1989.0       3 THE CRESCENT  PO272DD
# 22711    1977.0     64 CLARENCE ROAD  SW207UU
# 23474    1925.0      13 STANLEY ROAD  SW433XS
# 7934     2001.0    17 WOODLANDS ROAD  LS451GL
# 8067     1945.0    84 WOODLANDS ROAD  LS451GR
#
#                                                  allInfo
# 11100  m660xt013001emilywebbf26.051935.013springfield...
# 15495  po272dd003001ambevhing23.011989.03thecrescentp...
# 22711  sw207uu064002miamorrisf26.061977.064clarencero...
# 23474  sw433xs013002joshstewartm16.091925.013stanleyr...
# 7934   ls451gl017003mollymabshallf20.032001.017woodla...
# 8067   ls451gr084002harrygibsonm18.0101945.084woodlan...

# %%
census.iloc[[11100, 15495, 22711, 23474, 7934, 8067]]
# Out:
#        index      person_id pername1  pername2  sex  dob_day  dob_mon  \
# 2727    2727   M660XT013001    EMILY      WEBB    F     26.0        7
# 18117  18117  PO272DD003001    AMBER      KING  NaN     23.0        1
# 13752  13752  SW207UU064002      MIR  MORRISON    F     26.0        6
# 1603    1603  SW433XS013002   JOSHUA   STEWART    M     16.0        9
# 21171  21171  LS451GL017003    NOLLY  NARSHALL    F     20.0        3
# 4209    4209  LS451GR084002    HARRY    GIBSON    M     18.0       10
#
#        dob_year enumcap   enumpc  \
# 2727     1935.0     NaN   M660XT
# 18117    1989.0     NaN  PO272DD
# 13752    1977.0     NaN  SW207UU
# 1603     1925.0     NaN  SW433XS
# 21171    2001.0     NaN  LS451GJ
# 4209     1945.0     NaN  LS451QR
#
#                                              allInfo
# 2727         m660xt013001emilywebbf26.071935.0m660xt
# 18117       po272dd003001amberking23.011989.0po272dd
# 13752    sw207uu064002mirmorrisonf26.061977.0sw207uu
# 1603   sw433xs013002joshuastewartm16.091925.0sw433xs
# 21171  ls451gl017003nollynarshallf20.032001.0ls451gj
# 4209    ls451gr084002harrygibsonm18.0101945.0ls451qr

# %%
cis.iloc[[2727, 18117, 13752, 1603, 21171, 4209]]

# %%
cis.iloc[[7037, 18122, 20620, 17032, 23322, 13871]]
